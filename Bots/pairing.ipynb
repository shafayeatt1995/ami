# %%
x = ['o05_1h_away_cards',
'o05_1h_away_corners',
'o05_1h_away_goals',
'o05_1h_cards',
'o05_1h_corners',
'o05_1h_goals',
'o05_1h_home_cards',
'o05_1h_home_corners',
'o05_1h_home_goals',
'o05_2h_away_cards',
'o05_2h_away_corners',
'o05_2h_away_goals',
'o05_2h_cards',
'o05_2h_corners',
'o05_2h_goals',
'o05_2h_home_cards',
'o05_2h_home_corners',
'o05_2h_home_goals',

'o15_1h_away_cards',
'o15_1h_away_corners',
'o15_1h_away_goals',
'o15_1h_cards',
'o15_1h_corners',
'o15_1h_goals',
'o15_1h_home_cards',
'o15_1h_home_corners',
'o15_1h_home_goals',
'o15_2h_away_cards',
'o15_2h_away_corners',
'o15_2h_away_goals',
'o15_2h_cards',
'o15_2h_corners',
'o15_2h_goals',
'o15_2h_home_cards',
'o15_2h_home_corners',
'o15_2h_home_goals',
'o25_1h_away_corners',
'o25_1h_cards',
'o25_1h_corners',
'o25_1h_home_corners',
'o25_2h_away_corners',
'o25_2h_cards',
'o25_2h_corners',
'o25_2h_home_corners',
'o35_1h_away_corners',
'o35_1h_corners',
'o35_1h_home_corners',
'o35_2h_away_corners',
'o35_2h_corners',
'o35_2h_home_corners',
'o45_1h_away_corners',
'o45_1h_corners',
'o45_1h_home_corners',
'o45_2h_away_corners',
'o45_2h_corners',
'o45_2h_home_corners',
'o55_1h_corners',
'o55_2h_corners',]

# %%
y= ['o05_away_cards_1h',
'o05_away_corners_1h',
'o05_away_goals_1h',
'o05_cards_1h',
'o05_corners_1h',
'o05_goals_1h',
'o05_home_cards_1h',
'o05_home_corners_1h',
'o05_home_goals_1h',
'o05_away_cards_2h',
'o05_away_corners_2h',
'o05_away_goals_2h',
'o05_cards_2h',
'o05_corners_2h',
'o05_goals_2h',
'o05_home_cards_2h',
'o05_home_corners_2h',
'o05_home_goals_2h',

'o15_away_cards_1h',
'o15_away_corners_1h',
'o15_away_goals_1h',
'o15_cards_1h',
'o15_corners_1h',
'o15_goals_1h',
'o15_home_cards_1h',
'o15_home_corners_1h',
'o15_home_goals_1h',
'o15_away_cards_2h',
'o15_away_corners_2h',
'o15_away_goals_2h',
'o15_cards_2h',
'o15_corners_2h',
'o15_goals_2h',
'o15_home_cards_2h',
'o15_home_corners_2h',
'o15_home_goals_2h',

'o25_away_corners_1h',
'o25_cards_1h',
'o25_corners_1h',
'o25_home_corners_1h',
'o25_away_corners_2h',
'o25_cards_2h',
'o25_corners_2h',
'o25_home_corners_2h',
'o35_away_corners_1h',
'o35_corners_1h',
'o35_home_corners_1h',
'o35_away_corners_2h',
'o35_corners_2h',
'o35_home_corners_2h',
'o45_away_corners_1h',
'o45_corners_1h',
'o45_home_corners_1h',
'o45_away_corners_2h',
'o45_corners_2h',
'o45_home_corners_2h',
'o55_corners_1h',
'o55_corners_2h']

# %%
{"result."+i:"result."+j for i,j in zip(x,y)}
# Out:
# {'result.o05_1h_away_cards': 'result.o05_away_cards_1h',
#  'result.o05_1h_away_corners': 'result.o05_away_corners_1h',
#  'result.o05_1h_away_goals': 'result.o05_away_goals_1h',
#  'result.o05_1h_cards': 'result.o05_cards_1h',
#  'result.o05_1h_corners': 'result.o05_corners_1h',
#  'result.o05_1h_goals': 'result.o05_goals_1h',
#  'result.o05_1h_home_cards': 'result.o05_home_cards_1h',
#  'result.o05_1h_home_corners': 'result.o05_home_corners_1h',
#  'result.o05_1h_home_goals': 'result.o05_home_goals_1h',
#  'result.o05_2h_away_cards': 'result.o05_away_cards_2h',
#  'result.o05_2h_away_corners': 'result.o05_away_corners_2h',
#  'result.o05_2h_away_goals': 'result.o05_away_goals_2h',
#  'result.o05_2h_cards': 'result.o05_cards_2h',
#  'result.o05_2h_corners': 'result.o05_corners_2h',
#  'result.o05_2h_goals': 'result.o05_goals_2h',
#  'result.o05_2h_home_cards': 'result.o05_home_cards_2h',
#  'result.o05_2h_home_corners': 'result.o05_home_corners_2h',
# ...

# %%
x = []

# %%
y = []

# %%
{i:j for i,j in zip(x,y)}
# Out:
# {'o25_1h_away_corners': 'o25_away_corners_1h',
#  'o25_1h_cards': 'o25_cards_1h',
#  'o25_1h_corners': 'o25_corners_1h',
#  'o25_1h_home_corners': 'o25_home_corners_1h',
#  'o25_2h_away_corners': 'o25_away_corners_2h',
#  'o25_2h_cards': 'o25_cards_2h',
#  'o25_2h_corners': 'o25_corners_2h',
#  'o25_2h_home_corners': 'o25_home_corners_2h'}

# %%
x= []

# %%
y = []

# %%
{i:j for i,j in zip(x,y)}
# Out:
# {'o35_1h_away_corners': 'o35_away_corners_1h',
#  'o35_1h_corners': 'o35_corners_1h',
#  'o35_1h_home_corners': 'o35_home_corners_1h',
#  'o35_2h_away_corners': 'o35_away_corners_2h',
#  'o35_2h_corners': 'o35_corners_2h',
#  'o35_2h_home_corners': 'o35_home_corners_2h'}

# %%
x = []

# %%
y = []

# %%
{i:j for i,j in zip(x,y)}
# Out:
# {'o45_1h_away_corners': 'o45_away_corners_1h',
#  'o45_1h_corners': 'o45_corners_1h',
#  'o45_1h_home_corners': 'o45_home_corners_1h',
#  'o45_2h_away_corners': 'o45_away_corners_2h',
#  'o45_2h_corners': 'o45_corners_2h',
#  'o45_2h_home_corners': 'o45_home_corners_2h'}

# %%
# Out:
# ('o55_2h_corners',)

# %%
,
# Out:
# ('o55_corners_2h',)

# %%
import datetime

# %%
(datetime.datetime.today()+ datetime.timedelta(days=7)).strftime("%Y-%m-%d")
# Out:
# '2021-12-09'

# %%
"o(\d)5_(\d)h_cards_(for|against)"
# Out:
# 'o(\\d)5_(\\d)h_cards_(for|against)'

# %%
"o$15_cards_$3_$2h"
# Out:
# 'o$15_cards_$3_$2h'

# %%
keys= """o95_corners_h2h_per
o85_corners_h2h_per
o75_corners_h2h_per
o55_corners_1h_h2h_per
o55_cards_h2h_per
o45_corners_1h_h2h_per
o45_cards_h2h_per
o35_corners_1h_h2h_per
o35_cards_h2h_per
o105_corners_h2h_per
most_goals_2h_h2h_per
most_goals_1h_h2h_per
last_5.o35_goals_h2h_per
last_5.o25_goals_h2h_per
last_5.o15_goals_h2h_per
last_5.o15_goals_2h_h2h_per
last_5.o15_goals_1h_h2h_per
last_5.o05_goals_2h_h2h_per
last_5.o05_goals_1h_h2h_per
last_5.no_goals_1h_h2h_per
last_5.btts_o25_h2h_per
last_5.btts_h2h_per
last_10.o35_goals_h2h_per
last_10.o25_goals_h2h_per
last_10.o15_goals_h2h_per
last_10.o15_goals_2h_h2h_per
last_10.o15_goals_1h_h2h_per
last_10.o05_goals_2h_h2h_per
last_10.o05_goals_1h_h2h_per
last_10.no_goals_1h_h2h_per
last_10.btts_o25_h2h_per
last_10.btts_h2h_per
btts_or_o25_h2h_per"""

# %%
values = """+9.5 Corners % (H2H)
+8.5 Corners % (H2H)
+7.5 Corners % (H2H)
+5.5 1H Corners % (H2H) 
+5.5 Cards % (H2H)
+4.5 1H Corners % (H2H) 
+4.5 Cards % (H2H)
+3.5 1H Corners % (H2H) 
+3.5 Cards % (H2H)
+10.5 Corners % (H2H)
More Goals in 2H than 1H % (H2H)
More goals in 1H than 2H % (H2H)
+3.5 Goals % in last 5 Matches (H2H)
+2.5 Goals % in last 5 Matches (H2H)
+1.5 Goals % in last 5 Matches (H2H)
+1.5 2H Goals % in last 5 Matches (H2H)
+1.5 1H Goals % in last 5 Matches (H2H)
+0.5 2H Goals % in last 5 Matches (H2H)
+0.5 1H Goals % in last 5 Matches (H2H)
0-0 (1H) in last 5 matches % (H2H) 
BTTS & Over 2.5 Goals % in last 5 matches (H2H)
BTTS % in last 5 Matches (H2H)
+3.5 Goals % in last 10 Matches (H2H)
+2.5 Goals % in last 10 Matches (H2H)
+1.5 Goals % in last 10 Matches (H2H)
+1.5 2H Goals % in last 10 Matches (H2H)
+1.5 1H Goals % in last 10 Matches (H2H)
+0.5 2H Goals % in last 10 Matches (H2H)
+0.5 1H Goals % in last 10 Matches (H2H)
0-0 (1H) in last 10 matches % (H2H) 
BTTS & Over 2.5 Goals % in last 10 matches (H2H)
BTTS % in last 10 Matches (H2H)
BTTS or Over 2.5 Goals % (H2H)"""

# %%
keys = keys.splitlines()
values = values.splitlines()

# %%
{k:v for k,v in zip(keys, values)}
# Out:
# {'o95_corners_h2h_per': '+9.5 Corners % (H2H)',
#  'o85_corners_h2h_per': '+8.5 Corners % (H2H)',
#  'o75_corners_h2h_per': '+7.5 Corners % (H2H)',
#  'o55_corners_1h_h2h_per': '+5.5 1H Corners % (H2H) ',
#  'o55_cards_h2h_per': '+5.5 Cards % (H2H)',
#  'o45_corners_1h_h2h_per': '+4.5 1H Corners % (H2H) ',
#  'o45_cards_h2h_per': '+4.5 Cards % (H2H)',
#  'o35_corners_1h_h2h_per': '+3.5 1H Corners % (H2H) ',
#  'o35_cards_h2h_per': '+3.5 Cards % (H2H)',
#  'o105_corners_h2h_per': '+10.5 Corners % (H2H)',
#  'most_goals_2h_h2h_per': 'More Goals in 2H than 1H % (H2H)',
#  'most_goals_1h_h2h_per': 'More goals in 1H than 2H % (H2H)',
#  'last_5.o35_goals_h2h_per': '+3.5 Goals % in last 5 Matches (H2H)',
#  'last_5.o25_goals_h2h_per': '+2.5 Goals % in last 5 Matches (H2H)',
#  'last_5.o15_goals_h2h_per': '+1.5 Goals % in last 5 Matches (H2H)',
#  'last_5.o15_goals_2h_h2h_per': '+1.5 2H Goals % in last 5 Matches (H2H)',
# ...

# %%
label_hmap = {'played_home': 'Games Played (Home)',
              'played_away': 'Games Played (Away)',
              'played_overall': 'Games Played (Overall)',
              'first_corner_total_avg': 'First Corner Avg ',
              'first_corner_against_avg': 'First Corner Against Avg ',
              'first_corner_for_avg': 'First Corner For Avg ',
              'first_goal_total_avg': 'First Goal Avg ',
              'first_goal_against_avg': 'First Goal Against Avg ',
              'first_goal_for_avg': 'First Goal For Avg ',
              'goal_timings_for': 'Goal Timing For ',
              'goal_timings_against': 'Goal Timing Against ',
              'goal_timings_all': 'Goal Timing All ',
              'goal_timings_mean': 'Goal Timing Mean ',
              'corner_timings_for': 'Corner Timing For ',
              'corner_timings_against': 'Corner Timing Against ',
              'corner_timings_all': 'Corner Timing All ',
              'corner_timings_mean': 'Corner Timing Mean ',
              'won_home': 'Game Won (Home)',
              'won_away': 'Game Won (Away)',
              'won_overall': 'Game Won (Overall)',
              'won_home_per': 'Games Won % (Home)',
              'won_away_per': 'Games Won % (Away)',
              'won_overall_per': 'Games Won % (Overall)',
              'drawn_home': 'Games Draw (Home)',
              'drawn_away': 'Games Draw (Away)',
              'drawn_overall': 'Games Draw (Overall)',
              'drawn_home_per': 'Games Draw % (Home)',
              'drawn_away_per': 'Games Draw % (Away)',
              'drawn_overall_per': 'Games Draw % (Overall)',
              'lost_home': 'Games Lost (Home)',
              'lost_away': 'Games Lost (Away)',
              'lost_overall': 'Games Lost (Overall)',
              'lost_home_per': 'Games Lost % (Home)',
              'lost_away_per': 'Games Lost % (Away)',
              'lost_overall_per': 'Games Lost % (Overall)',
              'fts_home': 'Failed to Score (Home)',
              'fts_away': 'Failed to Score (Away)',
              'fts_overall': 'Failed to Score (Overall)',
              'fts_home_per': 'Failed to Score % (Home)',
              'fts_away_per': 'Failed to Score % (Away)',
              'fts_overall_per': 'Failed to Score % (Overall)',
              'goal_difference_home': 'Goall Difference (Home)',
              'goal_difference_away': 'Goall Difference (Away)',
              'goal_difference_overall': 'Goall Difference (Overall)',
              'btts_home': 'BTTS (Home)',
              'btts_away': 'BTTS (Away)',
              'btts_overall': 'BTTS (Overall)',
              'btts_home_per': 'BTTS % (Home)',
              'btts_away_per': 'BTTS % (Away)',
              'btts_overall_per': 'BTTS % (Overall)',
              'o05_goals_1h_home': '+0.5 1H Goals (Home)',
              'o05_goals_1h_away': '+0.5 1H Goals (Away)',
              'o05_goals_1h_overall': '+0.5 1H Goals (Overall)',
              'o05_goals_1h_home_per': '+0.5 1H Goals % (Home)',
              'o05_goals_1h_away_per': '+0.5 1H Goals % (Away)',
              'o05_goals_1h_overall_per': '+0.5 1H Goals % (Overall)',
              'o15_goals_1h_home': '+1.5 1H Goals (Home)',
              'o15_goals_1h_away': '+1.5 1H Goals (Away)',
              'o15_goals_1h_overall': '+1.5 1H Goals (Overall)',
              'o15_goals_1h_home_per': '+1.5 1H Goals % (Home)',
              'o15_goals_1h_away_per': '+1.5 1H Goals % (Away)',
              'o15_goals_1h_overall_per': '+1.5 1H Goals % (Overall)',
              'o05_goals_2h_home': '+0.5 2H Goals (Home)',
              'o05_goals_2h_away': '+0.5 2H Goals (Away)',
              'o05_goals_2h_overall': '+0.5 2H Goals (Overall)',
              'o05_goals_2h_home_per': '+0.5 2H Goals % (Home)',
              'o05_goals_2h_away_per': '+0.5 2H Goals % (Away)',
              'o05_goals_2h_overall_per': '+0.5 2H Goals % (Overall)',
              'o15_goals_2h_home': '+1.5 2H Goals (Home)',
              'o15_goals_2h_away': '+1.5 2H Goals (Away)',
              'o15_goals_2h_overall': '+1.5 2H Goals (Overall)',
              'o15_goals_2h_home_per': '+1.5 2H Goals % (Home)',
              'o15_goals_2h_away_per': '+1.5 2H Goals % (Away)',
              'o15_goals_2h_overall_per': '+1.5 2H Goals % (Overall)',
              'clean_sheets_home': 'Clean Sheets (Home)',
              'clean_sheets_away': 'Clean Sheets (Away)',
              'clean_sheets_overall': 'Clean Sheets (Overall)',
              'clean_sheets_home_per': 'Clean Sheets % (Home)',
              'clean_sheets_away_per': 'Clean Sheets % (Away)',
              'clean_sheets_overall_per': 'Clean Sheets % (Overall)',
              'o05_goals_home': '+0.5 Goals (Home)',
              'o05_goals_away': '+0.5 Goals (Away)',
              'o05_goals_overall': '+0.5 Goals (Overall)',
              'o05_goals_home_per': '+0.5 Goals % (Home)',
              'o05_goals_away_per': '+0.5 Goals % (Away)',
              'o05_goals_overall_per': '+0.5 Goals % (Overall)',
              'o15_goals_home': '+1.5 Goals (Home)',
              'o15_goals_away': '+1.5 Goals (Away)',
              'o15_goals_overall': '+1.5 Goals (Overall)',
              'o15_goals_home_per': '+1.5 Goals % (Home)',
              'o15_goals_away_per': '+1.5 Goals % (Away)',
              'o15_goals_overall_per': '+1.5 Goals % (Overall)',
              'o25_goals_home': '+2.5 Goals (Home)',
              'o25_goals_away': '+2.5 Goals (Away)',
              'o25_goals_overall': '+2.5 Goals (Overall)',
              'o25_goals_home_per': '+2.5 Goals % (Home)',
              'o25_goals_away_per': '+2.5 Goals % (Away)',
              'o25_goals_overall_per': '+2.5 Goals % (Overall)',
              'o35_goals_home': '+3.5 Goals (Home)',
              'o35_goals_away': '+3.5 Goals (Away)',
              'o35_goals_overall': '+3.5 Goals (Overall)',
              'o35_goals_home_per': '+3.5 Goals % (Home)',
              'o35_goals_away_per': '+3.5 Goals % (Away)',
              'o35_goals_overall_per': '+3.5 Goals % (Overall)',
              'o55_corners_home': '+5.5 Corners (Home)',
              'o55_corners_away': '+5.5 Corners (Away)',
              'o55_corners_overall': '+5.5 Corners (Overall)',
              'o55_corners_home_per': '+5.5 Corners % (Home)',
              'o55_corners_away_per': '+5.5 Corners % (Away)',
              'o55_corners_overall_per': '+5.5 Corners % (Overall)',
              'o65_corners_home': '+6.5 Corners (Home)',
              'o65_corners_away': '+6.5 Corners (Away)',
              'o65_corners_overall': '+6.5 Corners (Overall)',
              'o65_corners_home_per': '+6.5 Corners % (Home)',
              'o65_corners_away_per': '+6.5 Corners % (Away)',
              'o65_corners_overall_per': '+6.5 Corners % (Overall)',
              'o75_corners_home': '+7.5 Corners (Home)',
              'o75_corners_away': '+7.5 Corners (Away)',
              'o75_corners_overall': '+7.5 Corners (Overall)',
              'o75_corners_home_per': '+7.5 Corners % (Home)',
              'o75_corners_away_per': '+7.5 Corners % (Away)',
              'o75_corners_overall_per': '+7.5 Corners % (Overall)',
              'o85_corners_home': '+8.5 Corners (Home)',
              'o85_corners_away': '+8.5 Corners (Away)',
              'o85_corners_overall': '+8.5 Corners (Overall)',
              'o85_corners_home_per': '+8.5 Corners % (Home)',
              'o85_corners_away_per': '+8.5 Corners % (Away)',
              'o85_corners_overall_per': '+8.5 Corners % (Overall)',
              'o95_corners_home': '+9.5 Corners (Home)',
              'o95_corners_away': '+9.5 Corners (Away)',
              'o95_corners_overall': '+9.5 Corners (Overall)',
              'o95_corners_home_per': '+9.5 Corners % (Home)',
              'o95_corners_away_per': '+9.5 Corners % (Away)',
              'o95_corners_overall_per': '+9.5 Corners % (Overall)',
              'o105_corners_home': '+10.5 Corners (Home)',
              'o105_corners_away': '+10.5 Corners (Away)',
              'o105_corners_overall': '+10.5 Corners (Overall)',
              'o105_corners_home_per': '+10.5 Corners % (Home)',
              'o105_corners_away_per': '+10.5 Corners % (Away)',
              'o105_corners_overall_per': '+10.5 Corners % (Overall)',
              'o115_corners_home': '+11.5 Corners (Home)',
              'o115_corners_away': '+11.5 Corners (Away)',
              'o115_corners_overall': '+11.5 Corners (Overall)',
              'o115_corners_home_per': '+11.5 Corners % (Home)',
              'o115_corners_away_per': '+11.5 Corners % (Away)',
              'o115_corners_overall_per': '+11.5 Corners % (Overall)',
              'o125_corners_home': '+12.5 Corners (Home)',
              'o125_corners_away': '+12.5 Corners (Away)',
              'o125_corners_overall': '+12.5 Corners (Overall)',
              'o125_corners_home_per': '+12.5 Corners % (Home)',
              'o125_corners_away_per': '+12.5 Corners % (Away)',
              'o125_corners_overall_per': '+12.5 Corners % (Overall)',
              'o25_cards_home': '+2.5 Cards (Home)',
              'o25_cards_away': '+2.5 Cards (Away)',
              'o25_cards_overall': '+2.5 Cards (Overall)',
              'o25_cards_home_per': '+2.5 Cards % (Home)',
              'o25_cards_away_per': '+2.5 Cards % (Away)',
              'o25_cards_overall_per': '+2.5 Cards % (Overall)',
              'o35_cards_home': '+3.5 Cards (Home)',
              'o35_cards_away': '+3.5 Cards (Away)',
              'o35_cards_overall': '+3.5 Cards (Overall)',
              'o35_cards_home_per': '+3.5 Cards % (Home)',
              'o35_cards_away_per': '+3.5 Cards % (Away)',
              'o35_cards_overall_per': '+3.5 Cards % (Overall)',
              'o45_cards_home': '+4.5 Cards (Home)',
              'o45_cards_away': '+4.5 Cards (Away)',
              'o45_cards_overall': '+4.5 Cards (Overall)',
              'o45_cards_home_per': '+4.5 Cards % (Home)',
              'o45_cards_away_per': '+4.5 Cards % (Away)',
              'o45_cards_overall_per': '+4.5 Cards % (Overall)',
              'o55_cards_home': '+5.5 Cards (Home)',
              'o55_cards_away': '+5.5 Cards (Away)',
              'o55_cards_overall': '+5.5 Cards (Overall)',
              'o55_cards_home_per': '+5.5 Cards % (Home)',
              'o55_cards_away_per': '+5.5 Cards % (Away)',
              'o55_cards_overall_per': '+5.5 Cards % (Overall)',
              'o65_cards_home': '+6.5 Cards (Home)',
              'o65_cards_away': '+6.5 Cards (Away)',
              'o65_cards_overall': '+6.5 Cards (Overall)',
              'o65_cards_home_per': '+6.5 Cards % (Home)',
              'o65_cards_away_per': '+6.5 Cards % (Away)',
              'o65_cards_overall_per': '+6.5 Cards % (Overall)',
              'btts_o25_home': 'BTTS & +2.5 Goals (Home)',
              'btts_o25_away': 'BTTS & +2.5 Goals (Away)',
              'btts_o25_overall': 'BTTS & +2.5 Goals (Overall)',
              'btts_o25_home_per': 'BTTS & +2.5 Goals % (Home)',
              'btts_o25_away_per': 'BTTS & +2.5 Goals % (Away)',
              'btts_o25_overall_per': 'BTTS & +2.5 Goals % (Overall)',
              'o25_corners_1h_home': '+2.5 1H Corners (Home)',
              'o25_corners_1h_away': '+2.5 1H Corners (Away)',
              'o25_corners_1h_overall': '+2.5 1H Corners (Overall)',
              'o25_corners_1h_home_per': '+2.5 1H Corners % (Home)',
              'o25_corners_1h_away_per': '+2.5 1H Corners % (Away)',
              'o25_corners_1h_overall_per': '+2.5 1H Corners % (Overall)',
              'o35_corners_1h_home': '+3.5 1H Corners (Home)',
              'o35_corners_1h_away': '+3.5 1H Corners (Away)',
              'o35_corners_1h_overall': '+3.5 1H Corners (Overall)',
              'o35_corners_1h_home_per': '+3.5 1H Corners % (Home)',
              'o35_corners_1h_away_per': '+3.5 1H Corners % (Away)',
              'o35_corners_1h_overall_per': '+3.5 1H Corners % (Overall)',
              'o45_corners_1h_home': '+4.5 1H Corners (Home)',
              'o45_corners_1h_away': '+4.5 1H Corners (Away)',
              'o45_corners_1h_overall': '+4.5 1H Corners (Overall)',
              'o45_corners_1h_home_per': '+4.5 1H Corners % (Home)',
              'o45_corners_1h_away_per': '+4.5 1H Corners % (Away)',
              'o45_corners_1h_overall_per': '+4.5 1H Corners % (Overall)',
              'o55_corners_1h_home': '+5.5 1H Corners (Home)',
              'o55_corners_1h_away': '+5.5 1H Corners (Away)',
              'o55_corners_1h_overall': '+5.5 1H Corners (Overall)',
              'o55_corners_1h_home_per': '+5.5 1H Corners % (Home)',
              'o55_corners_1h_away_per': '+5.5 1H Corners % (Away)',
              'o55_corners_1h_overall_per': '+5.5 1H Corners % (Overall)',
              'won_at_ht_home': 'Won at HT (Home)',
              'won_at_ht_away': 'Won at HT (Away)',
              'won_at_ht_overall': 'Won at HT (Overall)',
              'won_at_ht_home_per': 'Won at HT % (Home)',
              'won_at_ht_away_per': 'Won at HT % (Away)',
              'won_at_ht_overall_per': 'Won at HT % (Overall)',
              'drawn_at_ht_home': 'Draw at HT (Home)',
              'drawn_at_ht_away': 'Draw at HT (Away)',
              'drawn_at_ht_overall': 'Draw at HT (Overall)',
              'drawn_at_ht_home_per': 'Draw at HT % (Home)',
              'drawn_at_ht_away_per': 'Draw at HT % (Away)',
              'drawn_at_ht_overall_per': 'Draw at HT % (Overall)',
              'lost_at_ht_home': 'Lost at HT (Home)',
              'lost_at_ht_away': 'Lost at HT (Away)',
              'lost_at_ht_overall': 'Lost at HT (Overall)',
              'lost_at_ht_home_per': 'Lost at HT % (Home)',
              'lost_at_ht_away_per': 'Lost at HT % (Away)',
              'lost_at_ht_overall_per': 'Lost at HT % (Overall)',
              'corners_between_35_45_home': 'Corners Between 35-45 Min (Home)',
              'corners_between_35_45_away': 'Corners Between 35-45 Min (Away)',
              'corners_between_35_45_overall': 'Corners Between 35-45 Min (Overall)',
              'corners_between_35_45_home_per': 'Corners Between 35-45 Min % (Home)',
              'corners_between_35_45_away_per': 'Corners Between 35-45 Min % (Away)',
              'corners_between_35_45_overall_per': 'Corners Between 35-45 Min % (Overall)',
              'corners_between_80_90_home': 'Corners Between 80-90 Min (Home)',
              'corners_between_80_90_away': 'Corners Between 80-90 Min (Away)',
              'corners_between_80_90_overall': 'Corners Between 80-90 Min (Overall)',
              'corners_between_80_90_home_per': 'Corners Between 80-90 Min % (Home)',
              'corners_between_80_90_away_per': 'Corners Between 80-90 Min % (Away)',
              'corners_between_80_90_overall_per': 'Corners Between 80-90 Min % (Overall)',
              'goals_between_35_45_home': 'Goals Between 35-45 Min (Home)',
              'goals_between_35_45_away': 'Goals Between 35-45 Min (Away)',
              'goals_between_35_45_overall': 'Goals Between 35-45 Min (Overall)',
              'goals_between_35_45_home_per': 'Goals Between 35-45 Min % (Home)',
              'goals_between_35_45_away_per': 'Goals Between 35-45 Min % (Away)',
              'goals_between_35_45_overall_per': 'Goals Between 35-45 Min % (Overall)',
              'goals_between_80_90_home': 'Goals Between 80-90 Min (Home)',
              'goals_between_80_90_away': 'Goals Between 80-90 Min (Away)',
              'goals_between_80_90_overall': 'Goals Between 80-90 Min (Overall)',
              'goals_between_80_90_home_per': 'Goals Between 80-90 Min % (Home)',
              'goals_between_80_90_away_per': 'Goals Between 80-90 Min % (Away)',
              'goals_between_80_90_overall_per': 'Goals Between 80-90 Min % (Overall)',
              'no_goals_home': 'No Goals (Home)',
              'no_goals_away': 'No Goals (Away)',
              'no_goals_overall': 'No Goals (Overall)',
              'no_goals_home_per': 'No Goals % (Home)',
              'no_goals_away_per': 'No Goals % (Away)',
              'no_goals_overall_per': 'No Goals % (Overall)',
              'no_goals_1h_home': 'No Goals 1H (Home)',
              'no_goals_1h_away': 'No Goals 1H (Away)',
              'no_goals_1h_overall': 'No Goals 1H (Overall)',
              'no_goals_1h_home_per': 'No Goals 1H % (Home)',
              'no_goals_1h_away_per': 'No Goals 1H % (Away)',
              'no_goals_1h_overall_per': 'No Goals 1H % (Overall)',
              'no_goals_2h_home': 'No Goals 2H (Home)',
              'no_goals_2h_away': 'No Goals 2H (Away)',
              'no_goals_2h_overall': 'No Goals 2H (Overall)',
              'no_goals_2h_home_per': 'No Goals 2H % (Home)',
              'no_goals_2h_away_per': 'No Goals 2H % (Away)',
              'no_goals_2h_overall_per': 'No Goals 2H % (Overall)',
              'btts_or_o25_home': 'BTTS or +2.5 Goals (Home)',
              'btts_or_o25_away': 'BTTS or +2.5 Goals (Away)',
              'btts_or_o25_overall': 'BTTS or +2.5 Goals (Overall)',
              'btts_or_o25_home_per': 'BTTS or +2.5 Goals % (Home)',
              'btts_or_o25_away_per': 'BTTS or +2.5 Goals % (Away)',
              'btts_or_o25_overall_per': 'BTTS or +2.5 Goals % (Overall)',
              'goals_between_0_15_home': 'Goals Between 0-15 Mins (Home)',
              'goals_between_0_15_away': 'Goals Between 0-15 Mins (Away)',
              'goals_between_0_15_overall': 'Goals Between 0-15 Mins (Overall)',
              'goals_between_0_15_home_per': 'Goals Between 0-15 Mins % (Home)',
              'goals_between_0_15_away_per': 'Goals Between 0-15 Mins % (Away)',
              'goals_between_0_15_overall_per': 'Goals Between 0-15 Mins % (Overall)',
              'goals_between_0_15_for_home': 'Goals Between 0-15 Mins For (Home)',
              'goals_between_0_15_for_away': 'Goals Between 0-15 Mins For (Away)',
              'goals_between_0_15_for_overall': 'Goals Between 0-15 Mins For (Overall)',
              'goals_between_0_15_for_home_per': 'Goals Between 0-15 Mins For % (Home)',
              'goals_between_0_15_for_away_per': 'Goals Between 0-15 Mins For % (Away)',
              'goals_between_0_15_for_overall_per': 'Goals Between 0-15 Mins For % (Overall)',
              'goals_between_0_15_against_home': 'Goals Between 0-15 Mins Against (Home)',
              'goals_between_0_15_against_away': 'Goals Between 0-15 Mins Against (Away)',
              'goals_between_0_15_against_overall': 'Goals Between 0-15 Mins Against (Overall)',
              'goals_between_0_15_against_home_per': 'Goals Between 0-15 Mins Against % (Home)',
              'goals_between_0_15_against_away_per': 'Goals Between 0-15 Mins Against % (Away)',
              'goals_between_0_15_against_overall_per': 'Goals Between 0-15 Mins Against % (Overall)',
              'corners_between_0_10_home': 'Goals Between 0-15 Mins (Home)',
              'corners_between_0_10_away': 'Goals Between 0-10 Mins (Away)',
              'corners_between_0_10_overall': 'Goals Between 0-10 Mins (Overall)',
              'corners_between_0_10_home_per': 'Goals Between 0-10 Mins % (Home)',
              'corners_between_0_10_away_per': 'Goals Between 0-10 Mins % (Away)',
              'corners_between_0_10_overall_per': 'Goals Between 0-10 Mins % (Overall)',
              'corners_between_0_10_for_home': 'Goals Between 0-10 Mins For (Home)',
              'corners_between_0_10_for_away': 'Goals Between 0-10 Mins For (Away)',
              'corners_between_0_10_for_overall': 'Goals Between 0-10 Mins For (Overall)',
              'corners_between_0_10_for_home_per': 'Goals Between 0-10 Mins For % (Home)',
              'corners_between_0_10_for_away_per': 'Goals Between 0-10 Mins For % (Away)',
              'corners_between_0_10_for_overall_per': 'Goals Between 0-10 Mins For % (Overall)',
              'corners_between_0_10_against_home': 'Goals Between 0-10 Mins Against (Home)',
              'corners_between_0_10_against_away': 'Goals Between 0-10 Mins Against (Away)',
              'corners_between_0_10_against_overall': 'Goals Between 0-10 Mins Against (Overall)',
              'corners_between_0_10_against_home_per': 'Goals Between 0-10 Mins Against % (Home)',
              'corners_between_0_10_against_away_per': 'Goals Between 0-10 Mins Against % (Away)',
              'corners_between_0_10_against_overall_per': 'Goals Between 0-10 Mins Against % (Overall)',
              'scored_o05_home': 'Scored +0.5 Goals (Home)',
              'scored_o05_away': 'Scored +0.5 Goals (Away)',
              'scored_o05_overall': 'Scored +0.5 Goals (Overall)',
              'scored_o05_home_per': 'Scored +0.5 Goals % (Home)',
              'scored_o05_away_per': 'Scored +0.5 Goals % (Away)',
              'scored_o05_overall_per': 'Scored +0.5 Goals % (Overall)',
              'scored_o15_home': 'Scored +1.5 Goals (Home)',
              'scored_o15_away': 'Scored +1.5 Goals (Away)',
              'scored_o15_overall': 'Scored +1.5 Goals (Overall)',
              'scored_o15_home_per': 'Scored +1.5 Goals % (Home)',
              'scored_o15_away_per': 'Scored +1.5 Goals % (Away)',
              'scored_o15_overall_per': 'Scored +1.5 Goals % (Overall)',
              'scored_o25_home': 'Scored +2.5 Goals (Home)',
              'scored_o25_away': 'Scored +2.5 Goals (Away)',
              'scored_o25_overall': 'Scored +2.5 Goals (Overall)',
              'scored_o25_home_per': 'Scored +2.5 Goals % (Home)',
              'scored_o25_away_per': 'Scored +2.5 Goals % (Away)',
              'scored_o25_overall_per': 'Scored +2.5 Goals % (Overall)',
              'scored_o05_1h_home': 'Scored +0.5 1H Goals (Home)',
              'scored_o05_1h_away': 'Scored +0.5 1H Goals (Away)',
              'scored_o05_1h_overall': 'Scored +0.5 1H Goals (Overall)',
              'scored_o05_1h_home_per': 'Scored +0.5 1H Goals % (Home)',
              'scored_o05_1h_away_per': 'Scored +0.5 1H Goals % (Away)',
              'scored_o05_1h_overall_per': 'Scored +0.5 1H Goals % (Overall)',
              'scored_o15_1h_home': 'Scored +1.5 1H Goals (Home)',
              'scored_o15_1h_away': 'Scored +1.5 1H Goals (Away)',
              'scored_o15_1h_overall': 'Scored +1.5 1H Goals (Overall)',
              'scored_o15_1h_home_per': 'Scored +1.5 1H Goals % (Home)',
              'scored_o15_1h_away_per': 'Scored +1.5 1H Goals % (Away)',
              'scored_o15_1h_overall_per': 'Scored +1.5 1H Goals % (Overall)',
              'scored_o05_2h_home': 'Scored +0.5 2H Goals (Home)',
              'scored_o05_2h_away': 'Scored +0.5 2H Goals (Away)',
              'scored_o05_2h_overall': 'Scored +0.5 2H Goals (Overall)',
              'scored_o05_2h_home_per': 'Scored +0.5 2H Goals % (Home)',
              'scored_o05_2h_away_per': 'Scored +0.5 2H Goals % (Away)',
              'scored_o05_2h_overall_per': 'Scored +0.5 2H Goals % (Overall)',
              'scored_o15_2h_home': 'Scored +1.5 2H Goals (Home)',
              'scored_o15_2h_away': 'Scored +1.5 2H Goals (Away)',
              'scored_o15_2h_overall': 'Scored +1.5 2H Goals (Overall)',
              'scored_o15_2h_home_per': 'Scored +1.5 2H Goals % (Home)',
              'scored_o15_2h_away_per': 'Scored +1.5 2H Goals % (Away)',
              'scored_o15_2h_overall_per': 'Scored +1.5 2H Goals % (Overall)',
              'scored_after_70_home': 'Scored after 70th Min (Home)',
              'scored_after_70_away': 'Scored after 70th Min (Away)',
              'scored_after_70_overall': 'Scored after 70th Min (Overall)',
              'scored_after_70_home_per': 'Scored after 70th Min % (Home)',
              'scored_after_70_away_per': 'Scored after 70th Min % (Away)',
              'scored_after_70_overall_per': 'Scored after 70th Min % (Overall)',
              'conceded_after_70_home': 'Conceeded after 70th Min (Home)',
              'conceded_after_70_away': 'Conceeded after 70th Min (Away)',
              'conceded_after_70_overall': 'Conceeded after 70th Min (Overall)',
              'conceded_after_70_home_per': 'Conceeded after 70th Min % (Home)',
              'conceded_after_70_away_per': 'Conceeded after 70th Min % (Away)',
              'conceded_after_70_overall_per': 'Conceeded after 70th Min % (Overall)',
              'goals_after_70_home': 'Goals after 70th Min (Home)',
              'goals_after_70_away': 'Goals after 70th Min (Away)',
              'goals_after_70_overall': 'Goals after 70th Min (Overall)',
              'goals_after_70_home_per': 'Goals after 70th Min % (Home)',
              'goals_after_70_away_per': 'Goals after 70th Min % (Away)',
              'goals_after_70_overall_per': 'Goals after 70th Min % (Overall)',
              'scored_first_home': 'Scored First (Home)',
              'scored_first_away': 'Scored First (Away)',
              'scored_first_overall': 'Scored First (Overall)',
              'scored_first_home_per': 'Scored First % (Home)',
              'scored_first_away_per': 'Scored First % (Away)',
              'scored_first_overall_per': 'Scored First % (Overall)',
              'conceded_o05_home': 'Conceeded +0.5 Goals (Home)',
              'conceded_o05_away': 'Conceeded +0.5 Goals (Away)',
              'conceded_o05_overall': 'Conceeded +0.5 Goals (Overall)',
              'conceded_o05_home_per': 'Conceeded +0.5 Goals % (Home)',
              'conceded_o05_away_per': 'Conceeded +0.5 Goals % (Away)',
              'conceded_o05_overall_per': 'Conceeded +0.5 Goals % (Overall)',
              'conceded_o15_home': 'Conceeded +1.5 Goals (Home)',
              'conceded_o15_away': 'Conceeded +1.5 Goals (Away)',
              'conceded_o15_overall': 'Conceeded +1.5 Goals (Overall)',
              'conceded_o15_home_per': 'Conceeded +1.5 Goals % (Home)',
              'conceded_o15_away_per': 'Conceeded +1.5 Goals % (Away)',
              'conceded_o15_overall_per': 'Conceeded +1.5 Goals % (Overall)',
              'conceded_o25_home': 'Conceeded +2.5 Goals (Home)',
              'conceded_o25_away': 'Conceeded +2.5 Goals (Away)',
              'conceded_o25_overall': 'Conceeded +2.5 Goals (Overall)',
              'conceded_o25_home_per': 'Conceeded +2.5 Goals % (Home)',
              'conceded_o25_away_per': 'Conceeded +2.5 Goals % (Away)',
              'conceded_o25_overall_per': 'Conceeded +2.5 Goals % (Overall)',
              'conceded_o05_1h_home': 'Conceeded +0.5 1H Goals (Home)',
              'conceded_o05_1h_away': 'Conceeded +0.5 1H Goals (Away)',
              'conceded_o05_1h_overall': 'Conceeded +0.5 1H Goals (Overall)',
              'conceded_o05_1h_home_per': 'Conceeded +0.5 1H Goals % (Home)',
              'conceded_o05_1h_away_per': 'Conceeded +0.5 1H Goals % (Away)',
              'conceded_o05_1h_overall_per': 'Conceeded +0.5 1H Goals % (Overall)',
              'conceded_o15_1h_home': 'Conceeded +1.5 1H Goals (Home)',
              'conceded_o15_1h_away': 'Conceeded +1.5 1H Goals (Away)',
              'conceded_o15_1h_overall': 'Conceeded +1.5 1H Goals (Overall)',
              'conceded_o15_1h_home_per': 'Conceeded +1.5 1H Goals % (Home)',
              'conceded_o15_1h_away_per': 'Conceeded +1.5 1H Goals % (Away)',
              'conceded_o15_1h_overall_per': 'Conceeded +1.5 1H Goals % (Overall)',
              'conceded_o05_2h_home': 'Conceeded +0.5 2H Goals (Home)',
              'conceded_o05_2h_away': 'Conceeded +0.5 2H Goals (Away)',
              'conceded_o05_2h_overall': 'Conceeded +0.5 2H Goals (Overall)',
              'conceded_o05_2h_home_per': 'Conceeded +0.5 2H Goals % (Home)',
              'conceded_o05_2h_away_per': 'Conceeded +0.5 2H Goals % (Away)',
              'conceded_o05_2h_overall_per': 'Conceeded +0.5 2H Goals % (Overall)',
              'conceded_o15_2h_home': 'Conceeded +1.5 2H Goals (Home)',
              'conceded_o15_2h_away': 'Conceeded +1.5 2H Goals (Away)',
              'conceded_o15_2h_overall': 'Conceeded +1.5 2H Goals (Overall)',
              'conceded_o15_2h_home_per': 'Conceeded +1.5 2H Goals % (Home)',
              'conceded_o15_2h_away_per': 'Conceeded +1.5 2H Goals % (Away)',
              'conceded_o15_2h_overall_per': 'Conceeded +1.5 2H Goals % (Overall)',
              'btts_1h_home': 'BTTS 1H (Home)',
              'btts_1h_away': 'BTTS 1H (Away)',
              'btts_1h_overall': 'BTTS 1H (Overall)',
              'btts_1h_home_per': 'BTTS 1H % (Home)',
              'btts_1h_away_per': 'BTTS 1H % (Away)',
              'btts_1h_overall_per': 'BTTS 1H % (Overall)',
              'btts_2h_home': 'BTTS 2H (Home)',
              'btts_2h_away': 'BTTS 2H (Away)',
              'btts_2h_overall': 'BTTS 2H (Overall)',
              'btts_2h_home_per': 'BTTS 2H % (Home)',
              'btts_2h_away_per': 'BTTS 2H % (Away)',
              'btts_2h_overall_per': 'BTTS 2H % (Overall)',
              'o05_cards_for_home': '+0.5 Cards (Home)',
              'o05_cards_for_away': '+0.5 Cards (Away)',
              'o05_cards_for_overall': '+0.5 Cards (Overall)',
              'o05_cards_for_home_per': '+0.5 Cards % (Home)',
              'o05_cards_for_away_per': '+0.5 Cards % (Away)',
              'o05_cards_for_overall_per': '+0.5 Cards % (Overall)',
              'o15_cards_for_home': '+1.5 Cards (Home)',
              'o15_cards_for_away': '+1.5 Cards (Away)',
              'o15_cards_for_overall': '+1.5 Cards (Overall)',
              'o15_cards_for_home_per': '+1.5 Cards % (Home)',
              'o15_cards_for_away_per': '+1.5 Cards % (Away)',
              'o15_cards_for_overall_per': '+1.5 Cards % (Overall)',
              'o25_cards_for_home': '+2.5 Cards (Home)',
              'o25_cards_for_away': '+2.5 Cards (Away)',
              'o25_cards_for_overall': '+2.5 Cards (Overall)',
              'o25_cards_for_home_per': '+2.5 Cards % (Home)',
              'o25_cards_for_away_per': '+2.5 Cards % (Away)',
              'o25_cards_for_overall_per': '+2.5 Cards % (Overall)',
              'o35_cards_for_home': '+3.5 Cards (Home)',
              'o35_cards_for_away': '+3.5 Cards (Away)',
              'o35_cards_for_overall': '+3.5 Cards (Overall)',
              'o35_cards_for_home_per': '+3.5 Cards % (Home)',
              'o35_cards_for_away_per': '+3.5 Cards % (Away)',
              'o35_cards_for_overall_per': '+3.5 Cards % (Overall)',
              'o05_cards_for_1h_home': '+0.5 1H Cards (Home)',
              'o05_cards_for_1h_away': '+0.5 1H Cards (Away)',
              'o05_cards_for_1h_overall': '+0.5 1H Cards (Overall)',
              'o05_cards_for_1h_home_per': '+0.5 1H Cards % (Home)',
              'o05_cards_for_1h_away_per': '+0.5 1H Cards % (Away)',
              'o05_cards_for_1h_overall_per': '+0.5 1H Cards % (Overall)',
              'o15_cards_for_1h_home': '+1.5 1H Cards (Home)',
              'o15_cards_for_1h_away': '+1.5 1H Cards (Away)',
              'o15_cards_for_1h_overall': '+1.5 1H Cards (Overall)',
              'o15_cards_for_1h_home_per': '+1.5 1H Cards % (Home)',
              'o15_cards_for_1h_away_per': '+1.5 1H Cards % (Away)',
              'o15_cards_for_1h_overall_per': '+1.5 1H Cards % (Overall)',
              'o05_cards_against_1h_home': '+0.5 1H Cards Against (Home)',
              'o05_cards_against_1h_away': '+0.5 1H Cards Against (Away)',
              'o05_cards_against_1h_overall': '+0.5 1H Cards Against (Overall)',
              'o05_cards_against_1h_home_per': '+0.5 1H Cards Against % (Home)',
              'o05_cards_against_1h_away_per': '+0.5 1H Cards Against % (Away)',
              'o05_cards_against_1h_overall_per': '+0.5 1H Cards Against % (Overall)',
              'o15_cards_against_1h_home': '+1.5 1H Cards Against (Home)',
              'o15_cards_against_1h_away': '+1.5 1H Cards Against (Away)',
              'o15_cards_against_1h_overall': '+1.5 1H Cards Against (Overall)',
              'o15_cards_against_1h_home_per': '+1.5 1H Cards Against % (Home)',
              'o15_cards_against_1h_away_per': '+1.5 1H Cards Against % (Away)',
              'o15_cards_against_1h_overall_per': '+1.5 1H Cards Against % (Overall)',
              'o05_cards_for_2h_home': '+0.5 2H Cards For (Home)',
              'o05_cards_for_2h_away': '+0.5 2H Cards For (Away)',
              'o05_cards_for_2h_overall': '+0.5 2H Cards For (Overall)',
              'o05_cards_for_2h_home_per': '+0.5 2H Cards For % (Home)',
              'o05_cards_for_2h_away_per': '+0.5 2H Cards For % (Away)',
              'o05_cards_for_2h_overall_per': '+0.5 2H Cards For % (Overall)',
              'o15_cards_for_2h_home': '+1.5 2H Cards For (Home)',
              'o15_cards_for_2h_away': '+1.5 2H Cards For (Away)',
              'o15_cards_for_2h_overall': '+1.5 2H Cards For (Overall)',
              'o15_cards_for_2h_home_per': '+1.5 2H Cards For % (Home)',
              'o15_cards_for_2h_away_per': '+1.5 2H Cards For % (Away)',
              'o15_cards_for_2h_overall_per': '+1.5 2H Cards For % (Overall)',
              'o05_cards_against_2h_home': '+0.5 2H Cards Against (Home)',
              'o05_cards_against_2h_away': '+0.5 2H Cards Against (Away)',
              'o05_cards_against_2h_overall': '+0.5 2H Cards Against (Overall)',
              'o05_cards_against_2h_home_per': '+0.5 2H Cards Against % (Home)',
              'o05_cards_against_2h_away_per': '+0.5 2H Cards Against % (Away)',
              'o05_cards_against_2h_overall_per': '+0.5 2H Cards Against % (Overall)',
              'o15_cards_against_2h_home': '+1.5 2H Cards Against (Home)',
              'o15_cards_against_2h_away': '+1.5 2H Cards Against (Away)',
              'o15_cards_against_2h_overall': '+1.5 2H Cards Against (Overall)',
              'o15_cards_against_2h_home_per': '+1.5 2H Cards Against % (Home)',
              'o15_cards_against_2h_away_per': '+1.5 2H Cards Against % (Away)',
              'o15_cards_against_2h_overall_per': '+1.5 2H Cards Against % (Overall)',
              'o05_cards_against_home': '+0.5 Cards Against (Home)',
              'o05_cards_against_away': '+0.5 Cards Against (Away)',
              'o05_cards_against_overall': '+0.5 Cards Against (Overall)',
              'o05_cards_against_home_per': '+0.5 Cards Against % (Home)',
              'o05_cards_against_away_per': '+0.5 Cards Against % (Away)',
              'o05_cards_against_overall_per': '+0.5 Cards Against % (Overall)',
              'o15_cards_against_home': '+1.5 Cards Against (Home)',
              'o15_cards_against_away': '+1.5 Cards Against (Away)',
              'o15_cards_against_overall': '+1.5 Cards Against (Overall)',
              'o15_cards_against_home_per': '+1.5 Cards Against % (Home)',
              'o15_cards_against_away_per': '+1.5 Cards Against % (Away)',
              'o15_cards_against_overall_per': '+1.5 Cards Against % (Overall)',
              'o25_cards_against_home': '+2.5 Cards Against (Home)',
              'o25_cards_against_away': '+2.5 Cards Against (Away)',
              'o25_cards_against_overall': '+2.5 Cards Against (Overall)',
              'o25_cards_against_home_per': '+2.5 Cards Against % (Home)',
              'o25_cards_against_away_per': '+2.5 Cards Against % (Away)',
              'o25_cards_against_overall_per': '+2.5 Cards Against % (Overall)',
              'o35_cards_against_home': '+3.5 Cards Against (Home)',
              'o35_cards_against_away': '+3.5 Cards Against (Away)',
              'o35_cards_against_overall': '+3.5 Cards Against (Overall)',
              'o35_cards_against_home_per': '+3.5 Cards Against % (Home)',
              'o35_cards_against_away_per': '+3.5 Cards Against % (Away)',
              'o35_cards_against_overall_per': '+3.5 Cards Against % (Overall)',
              'points_home': 'PPG (Points Per Game) (Home)',
              'points_away': 'PPG (Points Per Game) (Away)',
              'points_overall': 'PPG (Points Per Game) (Overall)',
              'points_home_avg': 'PPG (Points Per Game) Avg (Home)',
              'points_away_avg': 'PPG (Points Per Game) Avg (Away)',
              'points_overall_avg': 'PPG (Points Per Game) Avg (Overall)',
              'scored_home': 'Goal Scored (Home)',
              'scored_away': 'Goal Scored (Away)',
              'scored_overall': 'Goal Scored (Overall)',
              'scored_home_avg': 'Goal Scored Avg (Home)',
              'scored_away_avg': 'Goal Scored Avg (Away)',
              'scored_overall_avg': 'Goal Scored Avg (Overall)',
              'scored_1h_home': 'Goal Scored 1H (Home)',
              'scored_1h_away': 'Goal Scored 1H (Away)',
              'scored_1h_overall': 'Goal Scored 1H (Overall)',
              'scored_1h_home_avg': 'Goal Scored 1H Avg (Home)',
              'scored_1h_away_avg': 'Goal Scored 1H Avg (Away)',
              'scored_1h_overall_avg': 'Goal Scored 1H Avg (Overall)',
              'scored_2h_home': 'Goal Scored 2H (Home)',
              'scored_2h_away': 'Goal Scored 2H (Away)',
              'scored_2h_overall': 'Goal Scored 2H (Overall)',
              'scored_2h_home_avg': 'Goal Scored 2H Avg (Home)',
              'scored_2h_away_avg': 'Goal Scored 2H Avg (Away)',
              'scored_2h_overall_avg': 'Goal Scored 2H Avg (Overall)',
              'conceded_home': 'Goals Conceeded (Home)',
              'conceded_away': 'Goals Conceeded (Away)',
              'conceded_overall': 'Goals Conceeded (Overall)',
              'conceded_home_avg': 'Goals Conceeded Avg (Home)',
              'conceded_away_avg': 'Goals Conceeded Avg (Away)',
              'conceded_overall_avg': 'Goals Conceeded Avg (Overall)',
              'conceded_1h_home': 'Goals Conceeded 1H (Home)',
              'conceded_1h_away': 'Goals Conceeded 1H (Away)',
              'conceded_1h_overall': 'Goals Conceeded 1H (Overall)',
              'conceded_1h_home_avg': 'Goals Conceeded 1H Avg (Home)',
              'conceded_1h_away_avg': 'Goals Conceeded 1H Avg (Away)',
              'conceded_1h_overall_avg': 'Goals Conceeded 1H Avg (Overall)',
              'conceded_2h_home': 'Goals Conceeded 2H (Home)',
              'conceded_2h_away': 'Goals Conceeded 2H (Away)',
              'conceded_2h_overall': 'Goals Conceeded 2H (Overall)',
              'conceded_2h_home_avg': 'Goals Conceeded 2H Avg (Home)',
              'conceded_2h_away_avg': 'Goals Conceeded 2H Avg (Away)',
              'conceded_2h_overall_avg': 'Goals Conceeded 2H Avg (Overall)',
              'corners_for_home': 'Corners For (Home)',
              'corners_for_away': 'Corners For (Away)',
              'corners_for_overall': 'Corners For (Overall)',
              'corners_for_home_avg': 'Corners For Avg (Home)',
              'corners_for_away_avg': 'Corners For Avg (Away)',
              'corners_for_overall_avg': 'Corners For Avg (Overall)',
              'corners_against_home': 'Corners Against (Home)',
              'corners_against_away': 'Corners Against (Away)',
              'corners_against_overall': 'Corners Against (Overall)',
              'corners_against_home_avg': 'Corners Against Avg (Home)',
              'corners_against_away_avg': 'Corners Against Avg (Away)',
              'corners_against_overall_avg': 'Corners Against Avg (Overall)',
              'cards_for_home': 'Cards For (Home)',
              'cards_for_away': 'Cards For (Away)',
              'cards_for_overall': 'Cards For (Overall)',
              'cards_for_home_avg': 'Cards For Avg (Home)',
              'cards_for_away_avg': 'Cards For Avg (Away)',
              'cards_for_overall_avg': 'Cards For Avg (Overall)',
              'cards_against_home': 'Cards Against (Home)',
              'cards_against_away': 'Cards Against (Away)',
              'cards_against_overall': 'Cards Against (Overall)',
              'cards_against_home_avg': 'Cards Against Avg (Home)',
              'cards_against_away_avg': 'Cards Against Avg (Away)',
              'cards_against_overall_avg': 'Cards Against Avg (Overall)',
              'cards_total_home': 'Cards Total (Home)',
              'cards_total_away': 'Cards Total (Away)',
              'cards_total_overall': 'Cards Total (Overall)',
              'cards_total_home_avg': 'Cards Total Avg (Home)',
              'cards_total_away_avg': 'Cards Total Avg (Away)',
              'cards_total_overall_avg': 'Cards Total Avg (Overall)',
              'cards_for_1h_home': 'Cards For 1H (Home)',
              'cards_for_1h_away': 'Cards For 1H (Away)',
              'cards_for_1h_overall': 'Cards For 1H (Overall)',
              'cards_for_1h_home_avg': 'Cards For 1H Avg (Home)',
              'cards_for_1h_away_avg': 'Cards For 1H Avg (Away)',
              'cards_for_1h_overall_avg': 'Cards For 1H Avg (Overall)',
              'cards_against_1h_home': 'Cards Against 1H (Home)',
              'cards_against_1h_away': 'Cards Against 1H (Away)',
              'cards_against_1h_overall': 'Cards Against 1H (Overall)',
              'cards_against_1h_home_avg': 'Cards Against 1H Avg (Home)',
              'cards_against_1h_away_avg': 'Cards Against 1H Avg (Away)',
              'cards_against_1h_overall_avg': 'Cards Against 1H Avg (Overall)',
              'cards_total_1h_home': 'Cards Total 1H (Home)',
              'cards_total_1h_away': 'Cards Total 1H (Away)',
              'cards_total_1h_overall': 'Cards Total 1H (Overall)',
              'cards_total_1h_home_avg': 'Cards Total 1H Avg (Home)',
              'cards_total_1h_away_avg': 'Cards Total 1H Avg (Away)',
              'cards_total_1h_overall_avg': 'Cards Total 1H Avg (Overall)',
              'cards_for_2h_home': 'Cards For 2H (Home)',
              'cards_for_2h_away': 'Cards For 2H (Away)',
              'cards_for_2h_overall': 'Cards For 2H (Overall)',
              'cards_for_2h_home_avg': 'Cards For 2H Avg (Home)',
              'cards_for_2h_away_avg': 'Cards For 2H Avg (Away)',
              'cards_for_2h_overall_avg': 'Cards For 2H Avg (Overall)',
              'cards_against_2h_home': 'Cards Against 2H (Home)',
              'cards_against_2h_away': 'Cards Against 2H (Away)',
              'cards_against_2h_overall': 'Cards Against 2H (Overall)',
              'cards_against_2h_home_avg': 'Cards Against 2H Avg (Home)',
              'cards_against_2h_away_avg': 'Cards Against 2H Avg (Away)',
              'cards_against_2h_overall_avg': 'Cards Against 2H Avg (Overall)',
              'cards_total_2h_home': 'Cards Total 2H (Home)',
              'cards_total_2h_away': 'Cards Total 2H (Away)',
              'cards_total_2h_overall': 'Cards Total 2H (Overall)',
              'cards_total_2h_home_avg': 'Cards Total 2H Avg (Home)',
              'cards_total_2h_away_avg': 'Cards Total 2H Avg (Away)',
              'cards_total_2h_overall_avg': 'Cards Total 2H Avg (Overall)',
              'corners_for_1h_home': 'Corners For 1H (Home)',
              'corners_for_1h_away': 'Corners For 1H (Away)',
              'corners_for_1h_overall': 'Corners For 1H (Overall)',
              'corners_for_1h_home_avg': 'Corners For 1H Avg (Home)',
              'corners_for_1h_away_avg': 'Corners For 1H Avg (Away)',
              'corners_for_1h_overall_avg': 'Corners For 1H Avg (Overall)',
              'corners_against_1h_home': 'Corners Against 1H (Home)',
              'corners_against_1h_away': 'Corners Against 1H (Away)',
              'corners_against_1h_overall': 'Corners Against 1H (Overall)',
              'corners_against_1h_home_avg': 'Corners Against 1H Avg (Home)',
              'corners_against_1h_away_avg': 'Corners Against 1H Avg (Away)',
              'corners_against_1h_overall_avg': 'Corners Against 1H Avg (Overall)',
              'corners_total_1h_home': 'Corners Total 1H (Home)',
              'corners_total_1h_away': 'Corners Total 1H (Away)',
              'corners_total_1h_overall': 'Corners Total 1H (Overall)',
              'corners_total_1h_home_avg': 'Corners Total 1H Avg (Home)',
              'corners_total_1h_away_avg': 'Corners Total 1H Avg (Away)',
              'corners_total_1h_overall_avg': 'Corners Total 1H Avg (Overall)',
              'corners_for_2h_home': 'Corners For 2H (Home)',
              'corners_for_2h_away': 'Corners For 2H (Away)',
              'corners_for_2h_overall': 'Corners For 2H (Overall)',
              'corners_for_2h_home_avg': 'Corners For 2H Avg (Home)',
              'corners_for_2h_away_avg': 'Corners For 2H Avg (Away)',
              'corners_for_2h_overall_avg': 'Corners For 2H Avg (Overall)',
              'corners_against_2h_home': 'Corners Against 2H (Home)',
              'corners_against_2h_away': 'Corners Against 2H (Away)',
              'corners_against_2h_overall': 'Corners Against 2H (Overall)',
              'corners_against_2h_home_avg': 'Corners Against 2H Avg (Home)',
              'corners_against_2h_away_avg': 'Corners Against 2H Avg (Away)',
              'corners_against_2h_overall_avg': 'Corners Against 2H Avg (Overall)',
              'corners_total_2h_home': 'Corners Total 2H (Home)',
              'corners_total_2h_away': 'Corners Total 2H (Away)',
              'corners_total_2h_overall': 'Corners Total 2H (Overall)',
              'corners_total_2h_home_avg': 'Corners Total 2H Avg (Home)',
              'corners_total_2h_away_avg': 'Corners Total 2H Avg (Away)',
              'corners_total_2h_overall_avg': 'Corners Total 2H Avg (Overall)',
              'corners_total_home': 'Corners Total (Home)',
              'corners_total_away': 'Corners Total (Away)',
              'corners_total_overall': 'Corners Total (Overall)',
              'corners_total_home_avg': 'Corners Total Avg (Home)',
              'corners_total_away_avg': 'Corners Total Avg (Away)',
              'corners_total_overall_avg': 'Corners Total Avg (Overall)',
              'total_goals_home': 'Total Goals (Home)',
              'total_goals_away': 'Total Goals (Away)',
              'total_goals_overall': 'Total Goals (Overall)',
              'total_goals_home_avg': 'Total Goals Avg (Home)',
              'total_goals_away_avg': 'Total Goals Avg (Away)',
              'total_goals_overall_avg': 'Total Goals Avg (Overall)',
              'pre_odds.away_win': 'Away Win ',
              'pre_odds.away_win_ht': 'Away Win [HT] ',
              'pre_odds.away_win_or_draw': 'Double Chance [Draw Away] (2X) ',
              'pre_odds.btts': 'BTTS (Yes) ',
              'pre_odds.btts_1h': 'BTTS 1H (Yes) ',
              'pre_odds.btts_1h_no': 'BTTS 1H (No) ',
              'pre_odds.btts_2h': 'BTTS 2H (Yes) ',
              'pre_odds.btts_2h_no': 'BTTS 2H (No) ',
              'pre_odds.btts_no': 'BTTS (No) ',
              'pre_odds.dnb': 'Draw No Bet ',
              'pre_odds.dnb_away': 'Draw No Bet [Away] (2) ',
              'pre_odds.draw': 'Draw ',
              'pre_odds.draw_ht': 'Draw [HT] ',
              'pre_odds.e10_corners': 'Exactly 10 Total Corners ',
              'pre_odds.e11_corners': 'Exactly 11 Total Corners ',
              'pre_odds.e12_corners': 'Exactly 12 Total Corners ',
              'pre_odds.e7_corners': 'Exactly 7 Total Corners ',
              'pre_odds.e8_corners': 'Exactly 8 Total Corners ',
              'pre_odds.e9_corners': 'Exactly 9 Total Corners ',
              'pre_odds.home_win': 'Home Win ',
              'pre_odds.home_win_ht': 'Home Win [HT] ',
              'pre_odds.home_win_or_away_win': 'Double Chance [Home Away] (12) ',
              'pre_odds.home_win_or_draw': 'Double Chance [Home Draw] (1X) ',
              'pre_odds.o05_asian_corners': 'Over 0.5 Asian Corners ',
              'pre_odds.o05_asian_corners_1h': 'Over 0.5 Asian Corners (1st Half) ',
              'pre_odds.o05_goal_line_1h': 'Over 0.5 Goal Line (1st Half) ',
              'pre_odds.o05_goals': 'Match Goals Over 0.5 ',
              'pre_odds.o05_goals_1h': '1st Half Goals Over 0.5 ',
              'pre_odds.o105_asian_corners': 'Over 10.5 Asian Corners ',
              'pre_odds.o105_asian_corners_1h': 'Over 10.5 Asian Corners (1st Half) ',
              'pre_odds.o10_asian_corners': 'Over 10 Asian Corners ',
              'pre_odds.o10_asian_corners_1h': 'Over 10 Asian Corners (1st Half) ',
              'pre_odds.o10_corners': 'Over 10 Total Corners ',
              'pre_odds.o10_goal_line_1h': 'Over 1.0 Goal Line (1st Half) ',
              'pre_odds.o115_asian_corners': 'Over 11.5 Asian Corners ',
              'pre_odds.o115_asian_corners_1h': 'Over 11.5 Asian Corners (1st Half) ',
              'pre_odds.o11_asian_corners': 'Over 11 Asian Corners ',
              'pre_odds.o11_asian_corners_1h': 'Over 11 Asian Corners (1st Half) ',
              'pre_odds.o11_corners': 'Over 11 Total Corners ',
              'pre_odds.o125_asian_corners': 'Over 12.5 Asian Corners ',
              'pre_odds.o125_asian_corners_1h': 'Over 12.5 Asian Corners (1st Half) ',
              'pre_odds.o12_asian_corners': 'Over 12 Asian Corners ',
              'pre_odds.o12_asian_corners_1h': 'Over 12 Asian Corners (1st Half) ',
              'pre_odds.o12_corners': 'Over 12 Total Corners ',
              'pre_odds.o135_asian_corners': 'Over 13.5 Asian Corners ',
              'pre_odds.o135_asian_corners_1h': 'Over 13.5 Asian Corners (1st Half) ',
              'pre_odds.o13_asian_corners': 'Over 13 Asian Corners ',
              'pre_odds.o13_asian_corners_1h': 'Over 13 Asian Corners (1st Half) ',
              'pre_odds.o145_asian_corners': 'Over 14.5 Asian Corners ',
              'pre_odds.o145_asian_corners_1h': 'Over 14.5 Asian Corners (1st Half) ',
              'pre_odds.o14_asian_corners': 'Over 14 Asian Corners ',
              'pre_odds.o14_asian_corners_1h': 'Over 14 Asian Corners (1st Half) ',
              'pre_odds.o155_asian_corners': 'Over 15.5 Asian Corners ',
              'pre_odds.o15_asian_corners': 'Over 15 Asian Corners ',
              'pre_odds.o15_asian_corners_1h': 'Over 15 Asian Corners (1st Half) ',
              'pre_odds.o15_goal_line': 'Over 1.5 Goal Line ',
              'pre_odds.o15_goals': 'Match Goals Over 1.5 ',
              'pre_odds.o15_goals_1h': '1st Half Goals Over 1.5 ',
              'pre_odds.o165_asian_corners': 'Over 16.5 Asian Corners ',
              'pre_odds.o16_asian_corners': 'Over 16 Asian Corners ',
              'pre_odds.o175_asian_corners': 'Over 17.5 Asian Corners ',
              'pre_odds.o17_asian_corners': 'Over 17 Asian Corners ',
              'pre_odds.o185_asian_corners': 'Over 18.5 Asian Corners ',
              'pre_odds.o18_asian_corners': 'Over 18 Asian Corners ',
              'pre_odds.o195_asian_corners': 'Over 19.5 Asian Corners ',
              'pre_odds.o19_asian_corners': 'Over 19 Asian Corners ',
              'pre_odds.o1_asian_corners': 'Over 1 Asian Corners ',
              'pre_odds.o1_asian_corners_1h': 'Over 1 Asian Corners (1st Half) ',
              'pre_odds.o205_asian_corners': 'Over 20.5 Asian Corners ',
              'pre_odds.o20_asian_corners': 'Over 20 Asian Corners ',
              'pre_odds.o20_goal_line': 'Over 2.0 Goal Line ',
              'pre_odds.o215_asian_corners': 'Over 21.5 Asian Corners ',
              'pre_odds.o21_asian_corners': 'Over 21 Asian Corners ',
              'pre_odds.o225_asian_corners': 'Over 22.5 Asian Corners ',
              'pre_odds.o22_asian_corners': 'Over 22 Asian Corners ',
              'pre_odds.o235_asian_corners': 'Over 23.5 Asian Corners ',
              'pre_odds.o23_asian_corners': 'Over 23 Asian Corners ',
              'pre_odds.o245_asian_corners': 'Over 24.5 Asian Corners ',
              'pre_odds.o24_asian_corners': 'Over 24 Asian Corners ',
              'pre_odds.o25_asian_corners': 'Over 25 Asian Corners ',
              'pre_odds.o25_asian_corners_1h': 'Over 2.5 Asian Corners (1st Half) ',
              'pre_odds.o25_goal_line': 'Over 2.5 Goal Line ',
              'pre_odds.o25_goals': 'Match Goals Over 2.5 ',
              'pre_odds.o25_goals_1h': '1st Half Goals Over 2.5 ',
              'pre_odds.o2_asian_corners': 'Over 2 Asian Corners ',
              'pre_odds.o2_asian_corners_1h': 'Over 2 Asian Corners (1st Half) ',
              'pre_odds.o35_asian_corners': 'Over 3.5 Asian Corners ',
              'pre_odds.o35_asian_corners_1h': 'Over 3.5 Asian Corners (1st Half) ',
              'pre_odds.o35_goals': 'Match Goals Over 3.5 ',
              'pre_odds.o35_goals_1h': '1st Half Goals Over 3.5 ',
              'pre_odds.o3_asian_corners': 'Over 3 Asian Corners ',
              'pre_odds.o3_asian_corners_1h': 'Over 3 Asian Corners (1st Half) ',
              'pre_odds.o45_asian_corners': 'Over 4.5 Asian Corners ',
              'pre_odds.o45_asian_corners_1h': 'Over 4.5 Asian Corners (1st Half) ',
              'pre_odds.o45_goals': 'Match Goals Over 4.5 ',
              'pre_odds.o45_goals_1h': '1st Half Goals Over 4.5 ',
              'pre_odds.o4_asian_corners': 'Over 4 Asian Corners ',
              'pre_odds.o4_asian_corners_1h': 'Over 4 Asian Corners (1st Half) ',
              'pre_odds.o55_asian_corners': 'Over 5.5 Asian Corners ',
              'pre_odds.o55_asian_corners_1h': 'Over 5.5 Asian Corners (1st Half) ',
              'pre_odds.o55_goals': 'Match Goals Over 5.5 ',
              'pre_odds.o55_goals_1h': '1st Half Goals Over 5.5 ',
              'pre_odds.o5_asian_corners': 'Over 5 Asian Corners ',
              'pre_odds.o5_asian_corners_1h': 'Over 5 Asian Corners (1st Half) ',
              'pre_odds.o65_asian_corners': 'Over 6.5 Asian Corners ',
              'pre_odds.o65_asian_corners_1h': 'Over 6.5 Asian Corners (1st Half) ',
              'pre_odds.o65_goals': 'Match Goals Over 6.5 ',
              'pre_odds.o6_asian_corners': 'Over 6 Asian Corners ',
              'pre_odds.o6_asian_corners_1h': 'Over 6 Asian Corners (1st Half) ',
              'pre_odds.o75_asian_corners': 'Over 7.5 Asian Corners ',
              'pre_odds.o75_asian_corners_1h': 'Over 7.5 Asian Corners (1st Half) ',
              'pre_odds.o75_goals': 'Match Goals Over 7.5 ',
              'pre_odds.o7_asian_corners': 'Over 7 Asian Corners ',
              'pre_odds.o7_asian_corners_1h': 'Over 7 Asian Corners (1st Half) ',
              'pre_odds.o7_corners': 'Over 7 Total Corners ',
              'pre_odds.o85_asian_corners': 'Over 8.5 Asian Corners ',
              'pre_odds.o85_asian_corners_1h': 'Over 8.5 Asian Corners (1st Half) ',
              'pre_odds.o85_goals': 'Match Goals Over 8.5 ',
              'pre_odds.o8_asian_corners': 'Over 8 Asian Corners ',
              'pre_odds.o8_asian_corners_1h': 'Over 8 Asian Corners (1st Half) ',
              'pre_odds.o8_corners': 'Over 8 Total Corners ',
              'pre_odds.o95_asian_corners': 'Over 9.5 Asian Corners ',
              'pre_odds.o95_asian_corners_1h': 'Over 9.5 Asian Corners (1st Half) ',
              'pre_odds.o9_asian_corners': 'Over 9 Asian Corners ',
              'pre_odds.o9_asian_corners_1h': 'Over 9 Asian Corners (1st Half) ',
              'pre_odds.o9_corners': 'Over 9 Total Corners ',
              'pre_odds.u05_asian_corners': 'Under 0.5 Asian Corners ',
              'pre_odds.u05_asian_corners_1h': 'Under 0.5 Asian Corners (1st Half) ',
              'pre_odds.u05_goal_line_1h': 'Under 0.5 Goal Line (1st Half) ',
              'pre_odds.u05_goals': 'Match Goals Under 0.5 ',
              'pre_odds.u05_goals_1h': '1st Half Goals Under 0.5 ',
              'pre_odds.u105_asian_corners': 'Under 10.5 Asian Corners ',
              'pre_odds.u105_asian_corners_1h': 'Under 10.5 Asian Corners (1st Half) ',
              'pre_odds.u10_asian_corners': 'Under 10 Asian Corners ',
              'pre_odds.u10_asian_corners_1h': 'Under 10 Asian Corners (1st Half) ',
              'pre_odds.u10_corners': 'Under 10 Total Corners ',
              'pre_odds.u10_goal_line_1h': 'Under 1.0 Goal Line (1st Half) ',
              'pre_odds.u115_asian_corners': 'Under 11.5 Asian Corners ',
              'pre_odds.u115_asian_corners_1h': 'Under 11.5 Asian Corners (1st Half) ',
              'pre_odds.u11_asian_corners': 'Under 11 Asian Corners ',
              'pre_odds.u11_asian_corners_1h': 'Under 11 Asian Corners (1st Half) ',
              'pre_odds.u11_corners': 'Under 11 Total Corners ',
              'pre_odds.u125_asian_corners': 'Under 12.5 Asian Corners ',
              'pre_odds.u125_asian_corners_1h': 'Under 12.5 Asian Corners (1st Half) ',
              'pre_odds.u12_asian_corners': 'Under 12 Asian Corners ',
              'pre_odds.u12_asian_corners_1h': 'Under 12 Asian Corners (1st Half) ',
              'pre_odds.u12_corners': 'Under 12 Total Corners ',
              'pre_odds.u135_asian_corners': 'Under 13.5 Asian Corners ',
              'pre_odds.u135_asian_corners_1h': 'Under 13.5 Asian Corners (1st Half) ',
              'pre_odds.u13_asian_corners': 'Under 13 Asian Corners ',
              'pre_odds.u13_asian_corners_1h': 'Under 13 Asian Corners (1st Half) ',
              'pre_odds.u145_asian_corners': 'Under 14.5 Asian Corners ',
              'pre_odds.u145_asian_corners_1h': 'Under 14.5 Asian Corners (1st Half) ',
              'pre_odds.u14_asian_corners': 'Under 14 Asian Corners ',
              'pre_odds.u14_asian_corners_1h': 'Under 14 Asian Corners (1st Half) ',
              'pre_odds.u155_asian_corners': 'Under 15.5 Asian Corners ',
              'pre_odds.u15_asian_corners': 'Under 15 Asian Corners ',
              'pre_odds.u15_asian_corners_1h': 'Under 15 Asian Corners (1st Half) ',
              'pre_odds.u15_goal_line': 'Under 1.5 Goal Line ',
              'pre_odds.u15_goals': 'Match Goals Under 1.5 ',
              'pre_odds.u15_goals_1h': '1st Half Goals Under 1.5 ',
              'pre_odds.u165_asian_corners': 'Under 16.5 Asian Corners ',
              'pre_odds.u16_asian_corners': 'Under 16 Asian Corners ',
              'pre_odds.u175_asian_corners': 'Under 17.5 Asian Corners ',
              'pre_odds.u17_asian_corners': 'Under 17 Asian Corners ',
              'pre_odds.u185_asian_corners': 'Under 18.5 Asian Corners ',
              'pre_odds.u18_asian_corners': 'Under 18 Asian Corners ',
              'pre_odds.u195_asian_corners': 'Under 19.5 Asian Corners ',
              'pre_odds.u19_asian_corners': 'Under 19 Asian Corners ',
              'pre_odds.u1_asian_corners': 'Under 1 Asian Corners ',
              'pre_odds.u1_asian_corners_1h': 'Under 1 Asian Corners (1st Half) ',
              'pre_odds.u205_asian_corners': 'Under 20.5 Asian Corners ',
              'pre_odds.u20_asian_corners': 'Under 20 Asian Corners ',
              'pre_odds.u20_goal_line': 'Under 2.0 Goal Line ',
              'pre_odds.u215_asian_corners': 'Under 21.5 Asian Corners ',
              'pre_odds.u21_asian_corners': 'Under 21 Asian Corners ',
              'pre_odds.u225_asian_corners': 'Under 22.5 Asian Corners ',
              'pre_odds.u22_asian_corners': 'Under 22 Asian Corners ',
              'pre_odds.u235_asian_corners': 'Under 23.5 Asian Corners ',
              'pre_odds.u23_asian_corners': 'Under 23 Asian Corners ',
              'pre_odds.u245_asian_corners': 'Under 24.5 Asian Corners ',
              'pre_odds.u24_asian_corners': 'Under 24 Asian Corners ',
              'pre_odds.u25_asian_corners': 'Under 25 Asian Corners ',
              'pre_odds.u25_asian_corners_1h': 'Under 2.5 Asian Corners (1st Half) ',
              'pre_odds.u25_goal_line': 'Under 2.5 Goal Line ',
              'pre_odds.u25_goals': 'Match Goals Under 2.5 ',
              'pre_odds.u25_goals_1h': '1st Half Goals Under 2.5 ',
              'pre_odds.u2_asian_corners': 'Under 2 Asian Corners ',
              'pre_odds.u2_asian_corners_1h': 'Under 2 Asian Corners (1st Half) ',
              'pre_odds.u35_asian_corners': 'Under 3.5 Asian Corners ',
              'pre_odds.u35_asian_corners_1h': 'Under 3.5 Asian Corners (1st Half) ',
              'pre_odds.u35_goals': 'Match Goals Under 3.5 ',
              'pre_odds.u35_goals_1h': '1st Half Goals Under 3.5 ',
              'pre_odds.u3_asian_corners': 'Under 3 Asian Corners ',
              'pre_odds.u3_asian_corners_1h': 'Under 3 Asian Corners (1st Half) ',
              'pre_odds.u45_asian_corners': 'Under 4.5 Asian Corners ',
              'pre_odds.u45_asian_corners_1h': 'Under 4.5 Asian Corners (1st Half) ',
              'pre_odds.u45_goals': 'Match Goals Under 4.5 ',
              'pre_odds.u45_goals_1h': '1st Half Goals Under 4.5 ',
              'pre_odds.u4_asian_corners': 'Under 4 Asian Corners ',
              'pre_odds.u4_asian_corners_1h': 'Under 4 Asian Corners (1st Half) ',
              'pre_odds.u55_asian_corners': 'Under 5.5 Asian Corners ',
              'pre_odds.u55_asian_corners_1h': 'Under 5.5 Asian Corners (1st Half) ',
              'pre_odds.u55_goals': 'Match Goals Under 5.5 ',
              'pre_odds.u55_goals_1h': '1st Half Goals Under 5.5 ',
              'pre_odds.u5_asian_corners': 'Under 5 Asian Corners ',
              'pre_odds.u5_asian_corners_1h': 'Under 5 Asian Corners (1st Half) ',
              'pre_odds.u65_asian_corners': 'Under 6.5 Asian Corners ',
              'pre_odds.u65_asian_corners_1h': 'Under 6.5 Asian Corners (1st Half) ',
              'pre_odds.u65_goals': 'Match Goals Under 6.5 ',
              'pre_odds.u6_asian_corners': 'Under 6 Asian Corners ',
              'pre_odds.u6_asian_corners_1h': 'Under 6 Asian Corners (1st Half) ',
              'pre_odds.u75_asian_corners': 'Under 7.5 Asian Corners ',
              'pre_odds.u75_asian_corners_1h': 'Under 7.5 Asian Corners (1st Half) ',
              'pre_odds.u75_goals': 'Match Goals Under 7.5 ',
              'pre_odds.u7_asian_corners': 'Under 7 Asian Corners ',
              'pre_odds.u7_asian_corners_1h': 'Under 7 Asian Corners (1st Half) ',
              'pre_odds.u7_corners': 'Under 7 Total Corners ',
              'pre_odds.u85_asian_corners': 'Under 8.5 Asian Corners ',
              'pre_odds.u85_asian_corners_1h': 'Under 8.5 Asian Corners (1st Half) ',
              'pre_odds.u85_goals': 'Match Goals Under 8.5 ',
              'pre_odds.u8_asian_corners': 'Under 8 Asian Corners ',
              'pre_odds.u8_asian_corners_1h': 'Under 8 Asian Corners (1st Half) ',
              'pre_odds.u8_corners': 'Under 8 Total Corners ',
              'pre_odds.u95_asian_corners': 'Under 9.5 Asian Corners ',
              'pre_odds.u95_asian_corners_1h': 'Under 9.5 Asian Corners (1st Half) ',
              'pre_odds.u9_asian_corners': 'Under 9 Asian Corners ',
              'pre_odds.u9_asian_corners_1h': 'Under 9 Asian Corners (1st Half) ',
              'pre_odds.u9_corners': 'Under 9 Total Corners ',
              'pre_odds.win': 'Full Time Result [1X2] ',
              'pre_odds.win_ht': 'Half Time Result [1X2] ',
              'live_odds.away_win': 'Away Win ',
              'live_odds.away_win_ht': 'Away Win [HT] ',
              'live_odds.away_win_or_draw': 'Double Chance [Draw Away] (2X) ',
              'live_odds.btts': 'BTTS (Yes) ',
              'live_odds.btts_1h': 'BTTS 1H (Yes) ',
              'live_odds.btts_1h_no': 'BTTS 1H (No) ',
              'live_odds.btts_2h': 'BTTS 2H (Yes) ',
              'live_odds.btts_2h_no': 'BTTS 2H (No) ',
              'live_odds.btts_no': 'BTTS (No) ',
              'live_odds.dnb': 'Draw No Bet ',
              'live_odds.dnb_away': 'Draw No Bet [Away] (2) ',
              'live_odds.draw': 'Draw ',
              'live_odds.draw_ht': 'Draw [HT] ',
              'live_odds.e10_corners': 'Exactly 10 Total Corners ',
              'live_odds.e11_corners': 'Exactly 11 Total Corners ',
              'live_odds.e12_corners': 'Exactly 12 Total Corners ',
              'live_odds.e7_corners': 'Exactly 7 Total Corners ',
              'live_odds.e8_corners': 'Exactly 8 Total Corners ',
              'live_odds.e9_corners': 'Exactly 9 Total Corners ',
              'live_odds.home_win': 'Home Win ',
              'live_odds.home_win_ht': 'Home Win [HT] ',
              'live_odds.home_win_or_away_win': 'Double Chance [Home Away] (12) ',
              'live_odds.home_win_or_draw': 'Double Chance [Home Draw] (1X) ',
              'live_odds.o05_asian_corners': 'Over 0.5 Asian Corners ',
              'live_odds.o05_asian_corners_1h': 'Over 0.5 Asian Corners (1st Half) ',
              'live_odds.o05_goal_line_1h': 'Over 0.5 Goal Line (1st Half) ',
              'live_odds.o05_goals': 'Match Goals Over 0.5 ',
              'live_odds.o05_goals_1h': '1st Half Goals Over 0.5 ',
              'live_odds.o105_asian_corners': 'Over 10.5 Asian Corners ',
              'live_odds.o105_asian_corners_1h': 'Over 10.5 Asian Corners (1st Half) ',
              'live_odds.o10_asian_corners': 'Over 10 Asian Corners ',
              'live_odds.o10_asian_corners_1h': 'Over 10 Asian Corners (1st Half) ',
              'live_odds.o10_corners': 'Over 10 Total Corners ',
              'live_odds.o10_goal_line_1h': 'Over 1.0 Goal Line (1st Half) ',
              'live_odds.o115_asian_corners': 'Over 11.5 Asian Corners ',
              'live_odds.o115_asian_corners_1h': 'Over 11.5 Asian Corners (1st Half) ',
              'live_odds.o11_asian_corners': 'Over 11 Asian Corners ',
              'live_odds.o11_asian_corners_1h': 'Over 11 Asian Corners (1st Half) ',
              'live_odds.o11_corners': 'Over 11 Total Corners ',
              'live_odds.o125_asian_corners': 'Over 12.5 Asian Corners ',
              'live_odds.o125_asian_corners_1h': 'Over 12.5 Asian Corners (1st Half) ',
              'live_odds.o12_asian_corners': 'Over 12 Asian Corners ',
              'live_odds.o12_asian_corners_1h': 'Over 12 Asian Corners (1st Half) ',
              'live_odds.o12_corners': 'Over 12 Total Corners ',
              'live_odds.o135_asian_corners': 'Over 13.5 Asian Corners ',
              'live_odds.o135_asian_corners_1h': 'Over 13.5 Asian Corners (1st Half) ',
              'live_odds.o13_asian_corners': 'Over 13 Asian Corners ',
              'live_odds.o13_asian_corners_1h': 'Over 13 Asian Corners (1st Half) ',
              'live_odds.o145_asian_corners': 'Over 14.5 Asian Corners ',
              'live_odds.o145_asian_corners_1h': 'Over 14.5 Asian Corners (1st Half) ',
              'live_odds.o14_asian_corners': 'Over 14 Asian Corners ',
              'live_odds.o14_asian_corners_1h': 'Over 14 Asian Corners (1st Half) ',
              'live_odds.o155_asian_corners': 'Over 15.5 Asian Corners ',
              'live_odds.o15_asian_corners': 'Over 15 Asian Corners ',
              'live_odds.o15_asian_corners_1h': 'Over 15 Asian Corners (1st Half) ',
              'live_odds.o15_goal_line': 'Over 1.5 Goal Line ',
              'live_odds.o15_goals': 'Match Goals Over 1.5 ',
              'live_odds.o15_goals_1h': '1st Half Goals Over 1.5 ',
              'live_odds.o165_asian_corners': 'Over 16.5 Asian Corners ',
              'live_odds.o16_asian_corners': 'Over 16 Asian Corners ',
              'live_odds.o175_asian_corners': 'Over 17.5 Asian Corners ',
              'live_odds.o17_asian_corners': 'Over 17 Asian Corners ',
              'live_odds.o185_asian_corners': 'Over 18.5 Asian Corners ',
              'live_odds.o18_asian_corners': 'Over 18 Asian Corners ',
              'live_odds.o195_asian_corners': 'Over 19.5 Asian Corners ',
              'live_odds.o19_asian_corners': 'Over 19 Asian Corners ',
              'live_odds.o1_asian_corners': 'Over 1 Asian Corners ',
              'live_odds.o1_asian_corners_1h': 'Over 1 Asian Corners (1st Half) ',
              'live_odds.o205_asian_corners': 'Over 20.5 Asian Corners ',
              'live_odds.o20_asian_corners': 'Over 20 Asian Corners ',
              'live_odds.o20_goal_line': 'Over 2.0 Goal Line ',
              'live_odds.o215_asian_corners': 'Over 21.5 Asian Corners ',
              'live_odds.o21_asian_corners': 'Over 21 Asian Corners ',
              'live_odds.o225_asian_corners': 'Over 22.5 Asian Corners ',
              'live_odds.o22_asian_corners': 'Over 22 Asian Corners ',
              'live_odds.o235_asian_corners': 'Over 23.5 Asian Corners ',
              'live_odds.o23_asian_corners': 'Over 23 Asian Corners ',
              'live_odds.o245_asian_corners': 'Over 24.5 Asian Corners ',
              'live_odds.o24_asian_corners': 'Over 24 Asian Corners ',
              'live_odds.o25_asian_corners': 'Over 25 Asian Corners ',
              'live_odds.o25_asian_corners_1h': 'Over 2.5 Asian Corners (1st Half) ',
              'live_odds.o25_goal_line': 'Over 2.5 Goal Line ',
              'live_odds.o25_goals': 'Match Goals Over 2.5 ',
              'live_odds.o25_goals_1h': '1st Half Goals Over 2.5 ',
              'live_odds.o2_asian_corners': 'Over 2 Asian Corners ',
              'live_odds.o2_asian_corners_1h': 'Over 2 Asian Corners (1st Half) ',
              'live_odds.o35_asian_corners': 'Over 3.5 Asian Corners ',
              'live_odds.o35_asian_corners_1h': 'Over 3.5 Asian Corners (1st Half) ',
              'live_odds.o35_goals': 'Match Goals Over 3.5 ',
              'live_odds.o35_goals_1h': '1st Half Goals Over 3.5 ',
              'live_odds.o3_asian_corners': 'Over 3 Asian Corners ',
              'live_odds.o3_asian_corners_1h': 'Over 3 Asian Corners (1st Half) ',
              'live_odds.o45_asian_corners': 'Over 4.5 Asian Corners ',
              'live_odds.o45_asian_corners_1h': 'Over 4.5 Asian Corners (1st Half) ',
              'live_odds.o45_goals': 'Match Goals Over 4.5 ',
              'live_odds.o45_goals_1h': '1st Half Goals Over 4.5 ',
              'live_odds.o4_asian_corners': 'Over 4 Asian Corners ',
              'live_odds.o4_asian_corners_1h': 'Over 4 Asian Corners (1st Half) ',
              'live_odds.o55_asian_corners': 'Over 5.5 Asian Corners ',
              'live_odds.o55_asian_corners_1h': 'Over 5.5 Asian Corners (1st Half) ',
              'live_odds.o55_goals': 'Match Goals Over 5.5 ',
              'live_odds.o55_goals_1h': '1st Half Goals Over 5.5 ',
              'live_odds.o5_asian_corners': 'Over 5 Asian Corners ',
              'live_odds.o5_asian_corners_1h': 'Over 5 Asian Corners (1st Half) ',
              'live_odds.o65_asian_corners': 'Over 6.5 Asian Corners ',
              'live_odds.o65_asian_corners_1h': 'Over 6.5 Asian Corners (1st Half) ',
              'live_odds.o65_goals': 'Match Goals Over 6.5 ',
              'live_odds.o6_asian_corners': 'Over 6 Asian Corners ',
              'live_odds.o6_asian_corners_1h': 'Over 6 Asian Corners (1st Half) ',
              'live_odds.o75_asian_corners': 'Over 7.5 Asian Corners ',
              'live_odds.o75_asian_corners_1h': 'Over 7.5 Asian Corners (1st Half) ',
              'live_odds.o75_goals': 'Match Goals Over 7.5 ',
              'live_odds.o7_asian_corners': 'Over 7 Asian Corners ',
              'live_odds.o7_asian_corners_1h': 'Over 7 Asian Corners (1st Half) ',
              'live_odds.o7_corners': 'Over 7 Total Corners ',
              'live_odds.o85_asian_corners': 'Over 8.5 Asian Corners ',
              'live_odds.o85_asian_corners_1h': 'Over 8.5 Asian Corners (1st Half) ',
              'live_odds.o85_goals': 'Match Goals Over 8.5 ',
              'live_odds.o8_asian_corners': 'Over 8 Asian Corners ',
              'live_odds.o8_asian_corners_1h': 'Over 8 Asian Corners (1st Half) ',
              'live_odds.o8_corners': 'Over 8 Total Corners ',
              'live_odds.o95_asian_corners': 'Over 9.5 Asian Corners ',
              'live_odds.o95_asian_corners_1h': 'Over 9.5 Asian Corners (1st Half) ',
              'live_odds.o9_asian_corners': 'Over 9 Asian Corners ',
              'live_odds.o9_asian_corners_1h': 'Over 9 Asian Corners (1st Half) ',
              'live_odds.o9_corners': 'Over 9 Total Corners ',
              'live_odds.u05_asian_corners': 'Under 0.5 Asian Corners ',
              'live_odds.u05_asian_corners_1h': 'Under 0.5 Asian Corners (1st Half) ',
              'live_odds.u05_goal_line_1h': 'Under 0.5 Goal Line (1st Half) ',
              'live_odds.u05_goals': 'Match Goals Under 0.5 ',
              'live_odds.u05_goals_1h': '1st Half Goals Under 0.5 ',
              'live_odds.u105_asian_corners': 'Under 10.5 Asian Corners ',
              'live_odds.u105_asian_corners_1h': 'Under 10.5 Asian Corners (1st Half) ',
              'live_odds.u10_asian_corners': 'Under 10 Asian Corners ',
              'live_odds.u10_asian_corners_1h': 'Under 10 Asian Corners (1st Half) ',
              'live_odds.u10_corners': 'Under 10 Total Corners ',
              'live_odds.u10_goal_line_1h': 'Under 1.0 Goal Line (1st Half) ',
              'live_odds.u115_asian_corners': 'Under 11.5 Asian Corners ',
              'live_odds.u115_asian_corners_1h': 'Under 11.5 Asian Corners (1st Half) ',
              'live_odds.u11_asian_corners': 'Under 11 Asian Corners ',
              'live_odds.u11_asian_corners_1h': 'Under 11 Asian Corners (1st Half) ',
              'live_odds.u11_corners': 'Under 11 Total Corners ',
              'live_odds.u125_asian_corners': 'Under 12.5 Asian Corners ',
              'live_odds.u125_asian_corners_1h': 'Under 12.5 Asian Corners (1st Half) ',
              'live_odds.u12_asian_corners': 'Under 12 Asian Corners ',
              'live_odds.u12_asian_corners_1h': 'Under 12 Asian Corners (1st Half) ',
              'live_odds.u12_corners': 'Under 12 Total Corners ',
              'live_odds.u135_asian_corners': 'Under 13.5 Asian Corners ',
              'live_odds.u135_asian_corners_1h': 'Under 13.5 Asian Corners (1st Half) ',
              'live_odds.u13_asian_corners': 'Under 13 Asian Corners ',
              'live_odds.u13_asian_corners_1h': 'Under 13 Asian Corners (1st Half) ',
              'live_odds.u145_asian_corners': 'Under 14.5 Asian Corners ',
              'live_odds.u145_asian_corners_1h': 'Under 14.5 Asian Corners (1st Half) ',
              'live_odds.u14_asian_corners': 'Under 14 Asian Corners ',
              'live_odds.u14_asian_corners_1h': 'Under 14 Asian Corners (1st Half) ',
              'live_odds.u155_asian_corners': 'Under 15.5 Asian Corners ',
              'live_odds.u15_asian_corners': 'Under 15 Asian Corners ',
              'live_odds.u15_asian_corners_1h': 'Under 15 Asian Corners (1st Half) ',
              'live_odds.u15_goal_line': 'Under 1.5 Goal Line ',
              'live_odds.u15_goals': 'Match Goals Under 1.5 ',
              'live_odds.u15_goals_1h': '1st Half Goals Under 1.5 ',
              'live_odds.u165_asian_corners': 'Under 16.5 Asian Corners ',
              'live_odds.u16_asian_corners': 'Under 16 Asian Corners ',
              'live_odds.u175_asian_corners': 'Under 17.5 Asian Corners ',
              'live_odds.u17_asian_corners': 'Under 17 Asian Corners ',
              'live_odds.u185_asian_corners': 'Under 18.5 Asian Corners ',
              'live_odds.u18_asian_corners': 'Under 18 Asian Corners ',
              'live_odds.u195_asian_corners': 'Under 19.5 Asian Corners ',
              'live_odds.u19_asian_corners': 'Under 19 Asian Corners ',
              'live_odds.u1_asian_corners': 'Under 1 Asian Corners ',
              'live_odds.u1_asian_corners_1h': 'Under 1 Asian Corners (1st Half) ',
              'live_odds.u205_asian_corners': 'Under 20.5 Asian Corners ',
              'live_odds.u20_asian_corners': 'Under 20 Asian Corners ',
              'live_odds.u20_goal_line': 'Under 2.0 Goal Line ',
              'live_odds.u215_asian_corners': 'Under 21.5 Asian Corners ',
              'live_odds.u21_asian_corners': 'Under 21 Asian Corners ',
              'live_odds.u225_asian_corners': 'Under 22.5 Asian Corners ',
              'live_odds.u22_asian_corners': 'Under 22 Asian Corners ',
              'live_odds.u235_asian_corners': 'Under 23.5 Asian Corners ',
              'live_odds.u23_asian_corners': 'Under 23 Asian Corners ',
              'live_odds.u245_asian_corners': 'Under 24.5 Asian Corners ',
              'live_odds.u24_asian_corners': 'Under 24 Asian Corners ',
              'live_odds.u25_asian_corners': 'Under 25 Asian Corners ',
              'live_odds.u25_asian_corners_1h': 'Under 2.5 Asian Corners (1st Half) ',
              'live_odds.u25_goal_line': 'Under 2.5 Goal Line ',
              'live_odds.u25_goals': 'Match Goals Under 2.5 ',
              'live_odds.u25_goals_1h': '1st Half Goals Under 2.5 ',
              'live_odds.u2_asian_corners': 'Under 2 Asian Corners ',
              'live_odds.u2_asian_corners_1h': 'Under 2 Asian Corners (1st Half) ',
              'live_odds.u35_asian_corners': 'Under 3.5 Asian Corners ',
              'live_odds.u35_asian_corners_1h': 'Under 3.5 Asian Corners (1st Half) ',
              'live_odds.u35_goals': 'Match Goals Under 3.5 ',
              'live_odds.u35_goals_1h': '1st Half Goals Under 3.5 ',
              'live_odds.u3_asian_corners': 'Under 3 Asian Corners ',
              'live_odds.u3_asian_corners_1h': 'Under 3 Asian Corners (1st Half) ',
              'live_odds.u45_asian_corners': 'Under 4.5 Asian Corners ',
              'live_odds.u45_asian_corners_1h': 'Under 4.5 Asian Corners (1st Half) ',
              'live_odds.u45_goals': 'Match Goals Under 4.5 ',
              'live_odds.u45_goals_1h': '1st Half Goals Under 4.5 ',
              'live_odds.u4_asian_corners': 'Under 4 Asian Corners ',
              'live_odds.u4_asian_corners_1h': 'Under 4 Asian Corners (1st Half) ',
              'live_odds.u55_asian_corners': 'Under 5.5 Asian Corners ',
              'live_odds.u55_asian_corners_1h': 'Under 5.5 Asian Corners (1st Half) ',
              'live_odds.u55_goals': 'Match Goals Under 5.5 ',
              'live_odds.u55_goals_1h': '1st Half Goals Under 5.5 ',
              'live_odds.u5_asian_corners': 'Under 5 Asian Corners ',
              'live_odds.u5_asian_corners_1h': 'Under 5 Asian Corners (1st Half) ',
              'live_odds.u65_asian_corners': 'Under 6.5 Asian Corners ',
              'live_odds.u65_asian_corners_1h': 'Under 6.5 Asian Corners (1st Half) ',
              'live_odds.u65_goals': 'Match Goals Under 6.5 ',
              'live_odds.u6_asian_corners': 'Under 6 Asian Corners ',
              'live_odds.u6_asian_corners_1h': 'Under 6 Asian Corners (1st Half) ',
              'live_odds.u75_asian_corners': 'Under 7.5 Asian Corners ',
              'live_odds.u75_asian_corners_1h': 'Under 7.5 Asian Corners (1st Half) ',
              'live_odds.u75_goals': 'Match Goals Under 7.5 ',
              'live_odds.u7_asian_corners': 'Under 7 Asian Corners ',
              'live_odds.u7_asian_corners_1h': 'Under 7 Asian Corners (1st Half) ',
              'live_odds.u7_corners': 'Under 7 Total Corners ',
              'live_odds.u85_asian_corners': 'Under 8.5 Asian Corners ',
              'live_odds.u85_asian_corners_1h': 'Under 8.5 Asian Corners (1st Half) ',
              'live_odds.u85_goals': 'Match Goals Under 8.5 ',
              'live_odds.u8_asian_corners': 'Under 8 Asian Corners ',
              'live_odds.u8_asian_corners_1h': 'Under 8 Asian Corners (1st Half) ',
              'live_odds.u8_corners': 'Under 8 Total Corners ',
              'live_odds.u95_asian_corners': 'Under 9.5 Asian Corners ',
              'live_odds.u95_asian_corners_1h': 'Under 9.5 Asian Corners (1st Half) ',
              'live_odds.u9_asian_corners': 'Under 9 Asian Corners ',
              'live_odds.u9_asian_corners_1h': 'Under 9 Asian Corners (1st Half) ',
              'live_odds.u9_corners': 'Under 9 Total Corners ',
              'live_odds.win': 'Full Time Result [1X2] ',
              'live_odds.win_ht': 'Half Time Result [1X2] ',
              'probability.o05_away_goals_probability': 'Over 0.5 Goals (Away)',
              'probability.o15_away_goals_probability': 'Over 1.5 Goals (Away)',
              'probability.u15_away_goals_probability': 'Under 1.5 Goals (Away)',
              'probability.uo5_away_goals_probability': 'Under 0.5 Goals (Away)',
              'probability.away_win_probability': 'Away Win Probability',
              'probability.btts_probability': 'Both Teams to Score Probability',
              'probability.draw_probability': 'Draw Probability',
              'probability.o05_home_goals_probability': 'Over 0.5 Goals (Home) Probability',
              'probability.o15_home_goals_probability': 'Over 1.5 Goals (Home) Probability',
              'probability.u15_home_goals_probability': 'Under 1.5 Goals (Home) Probability',
              'probability.uo5_home_goals_probability': 'Under 0.5 Goals (Home) Probability',
              'probability.home_win_probability': 'Home Win Probability',
              'probability.o25_goals_probability': 'Over 2.5 Goals Probability',
              'probability.o35_goals_probability': 'Over 3.5 Goals Probability',
              'probability.u25_goals_probability': 'Under 2.5 Goals Probability',
              'probability.u35_goals_probability': 'Under 3.5 Goals Probability',
              'most_goals_1h_overall_per': 'Most goals 1H (Overall)',
              'most_goals_1h_home_per':	'Most goals 1H (Home)',
              'most_goals_1h_away_per': 'Most goals 1H (Away)',

              'most_goals_2h_overall_per': 'Most goals 2H (Overall)',
              'most_goals_2h_home_per': 'Most goals 2H (Home)',
              'most_goals_2h_away_per': 'Most goals 2H (Away)',

              'goals_after_75_overall_per': "Goals after 75' (Overall)",
              'goals_after_75_home_per': "Goals after 75' (Home)",
              'goals_after_75_away_per': "Goals after 75' (Away)",

              'corners_between_0_15_overall_per': '15 Min Corner (Overall)',
              'corners_between_0_15_home_per': '15 Min Corner (Home)',
              'corners_between_0_15_away_per': '15 Min Corner (Away)',

              'corners_between_31_45_overall_per': '31-45 Min Corner (Overall)',
              'corners_between_31_45_home_per': '31-45 Min Corner (Home)',
              'corners_between_31_45_away_per': '31-45 Min Corner (Away)',
              'corners_after_75_overall_per': "Corners after 75' (Overall)",
              'corners_after_75_home_per': "Corners after 75' (Home)",
              'corners_after_75_away_per': "Corners after 75' (Away)",

              'most_corners_1h_overall_per': 'Most corners 1H (Overall)',
              'most_corners_1h_home_per': 'Most corners 1H (Home)',
              'most_corners_1h_away_per': 'Most corners 1H (Away)',

              'most_corners_2h_overall_per': 'Most corners 2H (Overall)',
              'most_corners_2h_home_per': 'Most corners 2H (Home)',
              'most_corners_2h_away_per': 'Most corners 2H (Away)',

              'h2h_aggregate.o95_corners_h2h_per': '+9.5 Corners % (H2H)',
              'h2h_aggregate.o85_corners_h2h_per': '+8.5 Corners % (H2H)',
              'h2h_aggregate.o75_corners_h2h_per': '+7.5 Corners % (H2H)',
              'h2h_aggregate.o55_corners_1h_h2h_per': '+5.5 1H Corners % (H2H) ',
              'h2h_aggregate.o55_cards_h2h_per': '+5.5 Cards % (H2H)',
              'h2h_aggregate.o45_corners_1h_h2h_per': '+4.5 1H Corners % (H2H) ',
              'h2h_aggregate.o45_cards_h2h_per': '+4.5 Cards % (H2H)',
              'h2h_aggregate.o35_corners_1h_h2h_per': '+3.5 1H Corners % (H2H) ',
              'h2h_aggregate.o35_cards_h2h_per': '+3.5 Cards % (H2H)',
              'h2h_aggregate.o105_corners_h2h_per': '+10.5 Corners % (H2H)',
              'h2h_aggregate.most_goals_2h_h2h_per': 'More Goals in 2H than 1H % (H2H)',
              'h2h_aggregate.most_goals_1h_h2h_per': 'More goals in 1H than 2H % (H2H)',
              'h2h_aggregate.last_5.o35_goals_h2h_per': '+3.5 Goals % in last 5 Matches (H2H)',
              'h2h_aggregate.last_5.o25_goals_h2h_per': '+2.5 Goals % in last 5 Matches (H2H)',
              'h2h_aggregate.last_5.o15_goals_h2h_per': '+1.5 Goals % in last 5 Matches (H2H)',
              'h2h_aggregate.last_5.o15_goals_2h_h2h_per': '+1.5 2H Goals % in last 5 Matches (H2H)',
              'h2h_aggregate.last_5.o15_goals_1h_h2h_per': '+1.5 1H Goals % in last 5 Matches (H2H)',
              'h2h_aggregate.last_5.o05_goals_2h_h2h_per': '+0.5 2H Goals % in last 5 Matches (H2H)',
              'h2h_aggregate.last_5.o05_goals_1h_h2h_per': '+0.5 1H Goals % in last 5 Matches (H2H)',
              'h2h_aggregate.last_5.no_goals_1h_h2h_per': '0-0 (1H) in last 5 matches % (H2H) ',
              'h2h_aggregate.last_5.btts_o25_h2h_per': 'BTTS & Over 2.5 Goals % in last 5 matches (H2H)',
              'h2h_aggregate.last_5.btts_h2h_per': 'BTTS % in last 5 Matches (H2H)',
              'h2h_aggregate.last_10.o35_goals_h2h_per': '+3.5 Goals % in last 10 Matches (H2H)',
              'h2h_aggregate.last_10.o25_goals_h2h_per': '+2.5 Goals % in last 10 Matches (H2H)',
              'h2h_aggregate.last_10.o15_goals_h2h_per': '+1.5 Goals % in last 10 Matches (H2H)',
              'h2h_aggregate.last_10.o15_goals_2h_h2h_per': '+1.5 2H Goals % in last 10 Matches (H2H)',
              'h2h_aggregate.last_10.o15_goals_1h_h2h_per': '+1.5 1H Goals % in last 10 Matches (H2H)',
              'h2h_aggregate.last_10.o05_goals_2h_h2h_per': '+0.5 2H Goals % in last 10 Matches (H2H)',
              'h2h_aggregate.last_10.o05_goals_1h_h2h_per': '+0.5 1H Goals % in last 10 Matches (H2H)',
              'h2h_aggregate.last_10.no_goals_1h_h2h_per': '0-0 (1H) in last 10 matches % (H2H) ',
              'h2h_aggregate.last_10.btts_o25_h2h_per': 'BTTS & Over 2.5 Goals % in last 10 matches (H2H)',
              'h2h_aggregate.last_10.btts_h2h_per': 'BTTS % in last 10 Matches (H2H)',
              'h2h_aggregate.btts_or_o25_h2h_per': 'BTTS or Over 2.5 Goals % (H2H)',
              'league_position': "League Position",
              "live_odds.sum_of_teams.dnb": "Live Odds - Sum Of Teams - DNB",
              "live_odds.sum_of_teams.ft_result": "Live Odds - Sum Of Teams - FT Result",
              "live_odds.sum_of_teams.ht_result": "Live Odds - Sum Of Teams - HT Result",
              "live_odds.home.dnb": "Live Odds - Home - DNB",
              "live_odds.home.ft_result": "Live Odds - Home - FT Result",
              "live_odds.home.ht_result": "Live Odds - Home - HT Result",
              "live_odds.away.dnb": "Live Odds - Away - DNB",
              "live_odds.away.ft_result": "Live Odds - Away - FT Result",
              "live_odds.away.ht_result": "Live Odds - Away - HT Result",
              "live_odds.either_team.dnb": "Live Odds - Either Team - DNB",
              "live_odds.either_team.ft_result": "Live Odds - Either Team - FT Result",
              "live_odds.either_team.ht_result": "Live Odds - Either Team - HT Result",
              "live_odds.favorite.dnb": "Live Odds - Favorite - DNB",
              "live_odds.favorite.ft_result": "Live Odds - Favorite - FT Result",
              "live_odds.favorite.ht_result": "Live Odds - Favorite - HT Result",
              "live_odds.favorite_playing_home.dnb": "Live Odds - Favorite Playing Home - DNB",
              "live_odds.favorite_playing_home.ft_result": "Live Odds - Favorite Playing Home - FT Result",
              "live_odds.favorite_playing_home.ht_result": "Live Odds - Favorite Playing Home - HT Result",
              "live_odds.favorite_playing_away.dnb": "Live Odds - Favorite Playing Away - DNB",
              "live_odds.favorite_playing_away.ft_result": "Live Odds - Favorite Playing Away - FT Result",
              "live_odds.favorite_playing_away.ht_result": "Live Odds - Favorite Playing Away - HT Result",
              "live_odds.underdog.dnb": "Live Odds - Underdog - DNB",
              "live_odds.underdog.ft_result": "Live Odds - Underdog - FT Result",
              "live_odds.underdog.ht_result": "Live Odds - Underdog - HT Result",
              "live_odds.underdog_playing_home.dnb": "Live Odds - Underdog Playing Home - DNB",
              "live_odds.underdog_playing_home.ft_result": "Live Odds - Underdog Playing Home - FT Result",
              "live_odds.underdog_playing_home.ht_result": "Live Odds - Underdog Playing Home - HT Result",
              "live_odds.underdog_playing_away.dnb": "Live Odds - Underdog Playing Away - DNB",
              "live_odds.underdog_playing_away.ft_result": "Live Odds - Underdog Playing Away - FT Result",
              "live_odds.underdog_playing_away.ht_result": "Live Odds - Underdog Playing Away - HT Result",
              "live_odds.winning_team.dnb": "Live Odds - Winning Team - DNB",
              "live_odds.winning_team.ft_result": "Live Odds - Winning Team FT Result",
              "live_odds.winning_team.ht_result": "Live Odds - Winning Team - HT Result",
              "live_odds.losing_team.dnb": "Live Odds - Losing Team - DNB",
              "live_odds.losing_team.ft_result": "Live Odds - Losing Team FT Result",
              "live_odds.losing_team.ht_result": "Live Odds - Losing Team - HT Result",
              "pre_odds.sum_of_teams.dnb": "Pre Odds - Sum Of Teams - DNB",
              "pre_odds.sum_of_teams.ft_result": "Pre Odds - Sum Of Teams FT Result",
              "pre_odds.sum_of_teams.ht_result": "Pre Odds - Sum Of Teams - HT Result",
              "pre_odds.home.dnb": "Pre Odds - Home - DNB",
              "pre_odds.home.ft_result": "Pre Odds - Home FT Result",
              "pre_odds.home.ht_result": "Pre Odds - Home - HT Result",
              "pre_odds.away.dnb": "Pre Odds - Away - DNB",
              "pre_odds.away.ft_result": "Pre Odds - Away FT Result",
              "pre_odds.away.ht_result": "Pre Odds - Away - HT Result",
              "pre_odds.either_team.dnb": "Pre Odds - Either Team - DNB",
              "pre_odds.either_team.ft_result": "Pre Odds - Either Team FT Result",
              "pre_odds.either_team.ht_result": "Pre Odds - Either Team - HT Result",
              "pre_odds.favorite.dnb": "Pre Odds - Favorite - DNB",
              "pre_odds.favorite.ft_result": "Pre Odds - Favorite FT Result",
              "pre_odds.favorite.ht_result": "Pre Odds - Favorite - HT Result",
              "pre_odds.favorite_playing_home.dnb": "Pre Odds - Favorite Playing Home - DNB",
              "pre_odds.favorite_playing_home.ft_result": "Pre Odds - Favorite Playing Home - FT Result",
              "pre_odds.favorite_playing_home.ht_result": "Pre Odds - Favorite Playing Home - HT Result",
              "pre_odds.favorite_playing_away.dnb": "Pre Odds - Favorite Playing Away - DNB",
              "pre_odds.favorite_playing_away.ft_result": "Pre Odds - Favorite Playing Away - FT Result",
              "pre_odds.favorite_playing_away.ht_result": "Pre Odds - Favorite Playing Away - HT Result",
              "pre_odds.underdog.dnb": "Pre Odds - Underdog - DNB",
              "pre_odds.underdog.ft_result": "Pre Odds - Underdog - FT Result",
              "pre_odds.underdog.ht_result": "Pre Odds - Underdog - HT Result",
              "pre_odds.underdog_playing_home.dnb": "Pre Odds - Underdog Playing Home - DNB",
              "pre_odds.underdog_playing_home.ft_result": "Pre Odds - Underdog Playing Home - FT Result",
              "pre_odds.underdog_playing_home.ht_result": "Pre Odds - Underdog Playing Home - HT Result",
              "pre_odds.underdog_playing_away.dnb": "Pre Odds - Underdog Playing Away - DNB",
              "pre_odds.underdog_playing_away.ft_result": "Pre Odds - Underdog Playing Away - FT Result",
              "pre_odds.underdog_playing_away.ht_result": "Pre Odds - Underdog Playing Away - HT Result",
              "pre_odds.winning_team.dnb": "Pre Odds - Winning Team - DNB",
              "pre_odds.winning_team.ft_result": "Pre Odds - Winning Team - FT Result",
              "pre_odds.winning_team.ht_result": "Pre Odds - Winning Team - HT Result",
              "pre_odds.losing_team.dnb": "Pre Odds - Losing Team - DNB",
              "pre_odds.losing_team.ft_result": "Pre Odds - Losing Team - FT Result",
              "pre_odds.losing_team.ht_result": "Pre Odds - Losing Team - HT Result",
              }

# %%
import json
with open("data.json") as f:
  data = json.load(f)

# %%
data=  data["data"]

# %%
items = []
for i in data:
  if i["category"]in ["odds", "streak", "stats"]:
    continue
  if not i["home"]:
    if i["category"] in [ "h2h"]:
      items.append("h2h_aggregate."+i["code"])
    elif i["category"] in [ "probability"]:
      items.append(i["category"]+"."+i["code"])
    else:
      items.append(i["code"])
  else:
    items.append(i["home"])
    items.append(i["away"])
    items.append(i["overall"])

# %%
for i in items:
  if i not in label_hmap:
    print(i)
# Out:
# corner_timings_mean_avg
# offsides_against_home_avg
# offsides_against_away_avg
# offsides_against_overall_avg
# offsides_home_avg
# offsides_away_avg
# offsides_overall_avg
# offsides_for_home_avg
# offsides_for_away_avg
# offsides_for_overall_avg
# goal_timings_mean_avg
# goals_before_30_home_per
# goals_before_30_away_per
# goals_before_30_overall_per
